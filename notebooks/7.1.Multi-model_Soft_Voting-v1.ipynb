# %%
import numpy as np
import pandas as pd
import pickle
pd.set_option('max_columns', 100)
pd.set_option('max_rows', 200)

import matplotlib.pyplot as plt
import seaborn as sns

import gc, random, os

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import PowerTransformer, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score, balanced_accuracy_score, roc_auc_score
from sklearn.mixture import BayesianGaussianMixture

import lightgbm as lgb
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB

import warnings
warnings.filterwarnings("ignore")

from drive.MyDrive.Kaggle.Clustering_072022.src.functions import *

# %%
SEED = 1024
N_FOLDS = 10
N_CLUSTERS = 7
PATH = 'drive/MyDrive/Kaggle/Clustering_072022/'

# %%
data2 = pd.read_csv(PATH+'src/data_removed.csv', index_col='id')
data = pd.read_csv(PATH+'src/data.csv', index_col='id')
best_feats = data2.columns.tolist()
sub = pd.read_csv(PATH+'submissions/sample_submission.csv', index_col='Id')
cat_feats = data.columns[data.dtypes=='int'].tolist()
num_feats = data.columns[data.dtypes=='float'].tolist()

set_seed(3000)

# %%
ct = ColumnTransformer([('rs', RobustScaler(), num_feats)], remainder='passthrough')
pt = Pipeline([('ct', ct), ('pt', PowerTransformer())])

data = pd.DataFrame(pt.fit_transform(data), columns=num_feats+cat_feats)

def scores(preds, lib, df=data, verbose = True, compute_silhouette = True): 

    # Silhouette is very slow
    sil = 0
    if compute_silhouette:
        sil = silhouette_score(df, preds, metric='euclidean')

    s = (lib,
         sil, 
         calinski_harabasz_score(df, preds), 
         davies_bouldin_score(df, preds))

    if verbose:
        print(f"{s[0]} : Silhouette : {s[1]:.1%} | Calinski Harabasz : {s[2]:.1f} | Davis Bouldin : {s[3]:.3f}")

    return s

all_scores = []

# %%
BGM = BayesianGaussianMixture(
    n_components = N_CLUSTERS, 
    covariance_type = 'full', 
    random_state = SEED, 
    n_init = 5, tol=.0001)

BGM.fit(data[best_feats])
BGM_predict = BGM.predict(data[best_feats])
BGM_predict_proba = BGM.predict_proba(data[best_feats])

all_scores.append(scores(BGM_predict, lib="BayesianGaussianMixture after powertransformer"))
# Out:
# BayesianGaussianMixture after powertransformer : Silhouette : 1.5% | Calinski Harabasz : 1639.9 | Davis Bouldin : 5.591

# %%
# get trusted data to train LGB model.
proba_threshold = .69

data['predict'] = BGM_predict
data['predict_proba'] = 0
for n in range(N_CLUSTERS):
    data[f'predict_proba_{n}'] = BGM_predict_proba[:,n]
    data.loc[data.predict == n, 'predict_proba'] = data[f'predict_proba_{n}']
    
median_list = []
idxs = np.array([])
for n in range(N_CLUSTERS):
    median = data[data.predict==n]['predict_proba'].median()
    median_list.append(median)
    idx = data[(data.predict==n) & (data.predict_proba > proba_threshold)].index
    idxs = np.concatenate((idxs, idx))
    print(f'Class n°{n}  |  Median : {median:.4f}  |  Training data : {len(idx)/len(data[(data.predict==n)]):.1%}')
    
print(f'median mean: {np.mean(median_list)}')
X = data.loc[idxs][cat_feats+num_feats]
y = data.loc[idxs]['predict']
# Out:
# Class n°0  |  Median : 0.8684  |  Training data : 72.9%
# Class n°1  |  Median : 0.7311  |  Training data : 55.5%
# Class n°2  |  Median : 0.8671  |  Training data : 73.2%
# Class n°3  |  Median : 0.9833  |  Training data : 88.5%
# Class n°4  |  Median : 0.9074  |  Training data : 78.0%
# Class n°5  |  Median : 0.9119  |  Training data : 76.1%
# Class n°6  |  Median : 0.9376  |  Training data : 79.4%
# median mean: 0.8866725228749873

# %%
params_lgb = {'learning_rate': 0.07,'objective': 'multiclass','boosting': 'gbdt','verbosity': -1,'n_jobs': -1, 'num_classes':N_CLUSTERS} 

lgbm_predict_proba = 0 ; classif_scores = []

gkf = StratifiedKFold(N_FOLDS, shuffle=True, random_state = SEED)
for fold, (trn_idx, val_idx) in enumerate(gkf.split(X,y)):   

    X_trn = lgb.Dataset(X.iloc[trn_idx], y.iloc[trn_idx])
    X_val = lgb.Dataset(X.iloc[val_idx], y.iloc[val_idx])
    
    model = lgb.train(params = params_lgb, 
                train_set = X_trn, valid_sets =  X_val, 
                num_boost_round = 5000, 
                callbacks = [ lgb.early_stopping(stopping_rounds=300, verbose=True)])  

    y_pred_proba = model.predict(X.iloc[val_idx])
    y_pred = np.argmax(y_pred_proba, axis=1)
    
    s = (balanced_accuracy_score(y.iloc[val_idx], y_pred),
        roc_auc_score(y.iloc[val_idx], y_pred_proba, average="weighted", multi_class="ovo"))
    print(f"Fold n°{fold+1} on LGBM. AUC : {s[1]:.3f} | Accuracy : {s[0]:.1%}\n")
    classif_scores.append(s)

    lgbm_predict_proba += model.predict(data[best_feats]) / N_FOLDS
    
all_scores.append(scores(np.argmax(lgbm_predict_proba, axis=1), lib="LGBM after BayesianGaussianMixture - threshold 0.69"))

pd.DataFrame(classif_scores, columns = ["balanced_accuracy_score", "roc_auc_score"]).mean(0)
# Out:
# Streaming output truncated to the last 5000 lines.
# [884]	valid_0's multi_logloss: 0.0252393
# [885]	valid_0's multi_logloss: 0.0252232
# [886]	valid_0's multi_logloss: 0.0252196
# [887]	valid_0's multi_logloss: 0.0252185
# [888]	valid_0's multi_logloss: 0.0252084
# [889]	valid_0's multi_logloss: 0.0251964
# [890]	valid_0's multi_logloss: 0.0251821
# [891]	valid_0's multi_logloss: 0.0251912
# [892]	valid_0's multi_logloss: 0.0251901
# [893]	valid_0's multi_logloss: 0.0251461
# [894]	valid_0's multi_logloss: 0.0251286
# [895]	valid_0's multi_logloss: 0.025103
# [896]	valid_0's multi_logloss: 0.0250866
# [897]	valid_0's multi_logloss: 0.0251012
# [898]	valid_0's multi_logloss: 0.0251227
# [899]	valid_0's multi_logloss: 0.0251138
# [900]	valid_0's multi_logloss: 0.0251057
# [901]	valid_0's multi_logloss: 0.0251044
# [902]	valid_0's multi_logloss: 0.0250923
# [903]	valid_0's multi_logloss: 0.0251029
# [904]	valid_0's multi_logloss: 0.0250921
# [905]	valid_0's multi_logloss: 0.0250757
# [906]	valid_0's multi_logloss: 0.0250538
# [907]	valid_0's multi_logloss: 0.0250182
# [908]	valid_0's multi_logloss: 0.024984
# [909]	valid_0's multi_logloss: 0.0249669
# [910]	valid_0's multi_logloss: 0.024973
# [911]	valid_0's multi_logloss: 0.0249613
# [912]	valid_0's multi_logloss: 0.0249275
# [913]	valid_0's multi_logloss: 0.0249195
# [914]	valid_0's multi_logloss: 0.0249299
# [915]	valid_0's multi_logloss: 0.0249189
# [916]	valid_0's multi_logloss: 0.0249223
# [917]	valid_0's multi_logloss: 0.0249155
# [918]	valid_0's multi_logloss: 0.0249364
# [919]	valid_0's multi_logloss: 0.0249308
# [920]	valid_0's multi_logloss: 0.0249443
# [921]	valid_0's multi_logloss: 0.0249265
# [922]	valid_0's multi_logloss: 0.0249281
# [923]	valid_0's multi_logloss: 0.0249125
# [924]	valid_0's multi_logloss: 0.0248799
# [925]	valid_0's multi_logloss: 0.0248887
# [926]	valid_0's multi_logloss: 0.0248766
# [927]	valid_0's multi_logloss: 0.0248561
# [928]	valid_0's multi_logloss: 0.0248347
# [929]	valid_0's multi_logloss: 0.0248209
# [930]	valid_0's multi_logloss: 0.0248105
# [931]	valid_0's multi_logloss: 0.0247952
# [932]	valid_0's multi_logloss: 0.0248105
# [933]	valid_0's multi_logloss: 0.0248008
# [934]	valid_0's multi_logloss: 0.0247939
# [935]	valid_0's multi_logloss: 0.0248029
# [936]	valid_0's multi_logloss: 0.0247917
# [937]	valid_0's multi_logloss: 0.0247933
# [938]	valid_0's multi_logloss: 0.0247868
# [939]	valid_0's multi_logloss: 0.0247457
# [940]	valid_0's multi_logloss: 0.0247524
# [941]	valid_0's multi_logloss: 0.0247702
# [942]	valid_0's multi_logloss: 0.0247601
# [943]	valid_0's multi_logloss: 0.0247425
# [944]	valid_0's multi_logloss: 0.0247229
# [945]	valid_0's multi_logloss: 0.0246983
# [946]	valid_0's multi_logloss: 0.0247138
# [947]	valid_0's multi_logloss: 0.0247037
# [948]	valid_0's multi_logloss: 0.0247329
# [949]	valid_0's multi_logloss: 0.0247539
# [950]	valid_0's multi_logloss: 0.0247594
# [951]	valid_0's multi_logloss: 0.0247339
# [952]	valid_0's multi_logloss: 0.0247145
# [953]	valid_0's multi_logloss: 0.0247135
# [954]	valid_0's multi_logloss: 0.0247105
# [955]	valid_0's multi_logloss: 0.0247333
# [956]	valid_0's multi_logloss: 0.0247588
# [957]	valid_0's multi_logloss: 0.0247265
# [958]	valid_0's multi_logloss: 0.0247151
# [959]	valid_0's multi_logloss: 0.0246931
# [960]	valid_0's multi_logloss: 0.0247127
# [961]	valid_0's multi_logloss: 0.0247251
# [962]	valid_0's multi_logloss: 0.0247151
# [963]	valid_0's multi_logloss: 0.0246985
# [964]	valid_0's multi_logloss: 0.0247033
# [965]	valid_0's multi_logloss: 0.0246647
# [966]	valid_0's multi_logloss: 0.0246731
# [967]	valid_0's multi_logloss: 0.0246698
# [968]	valid_0's multi_logloss: 0.024707
# [969]	valid_0's multi_logloss: 0.024693
# [970]	valid_0's multi_logloss: 0.0246833
# [971]	valid_0's multi_logloss: 0.0246692
# [972]	valid_0's multi_logloss: 0.0246777
# [973]	valid_0's multi_logloss: 0.0247072
# [974]	valid_0's multi_logloss: 0.0247143
# [975]	valid_0's multi_logloss: 0.0247107
# [976]	valid_0's multi_logloss: 0.0247241
# [977]	valid_0's multi_logloss: 0.0247223
# [978]	valid_0's multi_logloss: 0.0247344
# [979]	valid_0's multi_logloss: 0.0247183
# [980]	valid_0's multi_logloss: 0.0246966
# [981]	valid_0's multi_logloss: 0.0246867
# [982]	valid_0's multi_logloss: 0.0246492
# [983]	valid_0's multi_logloss: 0.0246577
# [984]	valid_0's multi_logloss: 0.0246464
# [985]	valid_0's multi_logloss: 0.0246225
# [986]	valid_0's multi_logloss: 0.0246017
# [987]	valid_0's multi_logloss: 0.0246039
# [988]	valid_0's multi_logloss: 0.0246298
# [989]	valid_0's multi_logloss: 0.0245918
# [990]	valid_0's multi_logloss: 0.0245577
# [991]	valid_0's multi_logloss: 0.0245843
# [992]	valid_0's multi_logloss: 0.0245723
# [993]	valid_0's multi_logloss: 0.0245964
# [994]	valid_0's multi_logloss: 0.0246041
# [995]	valid_0's multi_logloss: 0.0246188
# [996]	valid_0's multi_logloss: 0.0246257
# [997]	valid_0's multi_logloss: 0.0246449
# [998]	valid_0's multi_logloss: 0.0246155
# [999]	valid_0's multi_logloss: 0.0246002
# [1000]	valid_0's multi_logloss: 0.0245757
# [1001]	valid_0's multi_logloss: 0.0245642
# [1002]	valid_0's multi_logloss: 0.0245677
# [1003]	valid_0's multi_logloss: 0.0245554
# [1004]	valid_0's multi_logloss: 0.0245236
# [1005]	valid_0's multi_logloss: 0.0245264
# [1006]	valid_0's multi_logloss: 0.0245034
# [1007]	valid_0's multi_logloss: 0.0244825
# [1008]	valid_0's multi_logloss: 0.0244917
# [1009]	valid_0's multi_logloss: 0.0244692
# [1010]	valid_0's multi_logloss: 0.024459
# [1011]	valid_0's multi_logloss: 0.0244436
# [1012]	valid_0's multi_logloss: 0.0244334
# [1013]	valid_0's multi_logloss: 0.0244319
# [1014]	valid_0's multi_logloss: 0.0244356
# [1015]	valid_0's multi_logloss: 0.0244086
# [1016]	valid_0's multi_logloss: 0.0243933
# [1017]	valid_0's multi_logloss: 0.0244201
# [1018]	valid_0's multi_logloss: 0.0244553
# [1019]	valid_0's multi_logloss: 0.0244083
# [1020]	valid_0's multi_logloss: 0.0244214
# [1021]	valid_0's multi_logloss: 0.024436
# [1022]	valid_0's multi_logloss: 0.0243999
# [1023]	valid_0's multi_logloss: 0.0244007
# [1024]	valid_0's multi_logloss: 0.0243917
# [1025]	valid_0's multi_logloss: 0.0243914
# [1026]	valid_0's multi_logloss: 0.0243955
# [1027]	valid_0's multi_logloss: 0.0243728
# [1028]	valid_0's multi_logloss: 0.0243822
# [1029]	valid_0's multi_logloss: 0.0243872
# [1030]	valid_0's multi_logloss: 0.0243704
# [1031]	valid_0's multi_logloss: 0.0243591
# [1032]	valid_0's multi_logloss: 0.0243774
# [1033]	valid_0's multi_logloss: 0.0243871
# [1034]	valid_0's multi_logloss: 0.0243973
# [1035]	valid_0's multi_logloss: 0.0244002
# [1036]	valid_0's multi_logloss: 0.0244049
# [1037]	valid_0's multi_logloss: 0.0244071
# [1038]	valid_0's multi_logloss: 0.0244061
# [1039]	valid_0's multi_logloss: 0.0243927
# [1040]	valid_0's multi_logloss: 0.0243799
# [1041]	valid_0's multi_logloss: 0.0243889
# [1042]	valid_0's multi_logloss: 0.0243944
# [1043]	valid_0's multi_logloss: 0.0244013
# [1044]	valid_0's multi_logloss: 0.0243799
# [1045]	valid_0's multi_logloss: 0.0243612
# [1046]	valid_0's multi_logloss: 0.0243639
# [1047]	valid_0's multi_logloss: 0.024345
# [1048]	valid_0's multi_logloss: 0.02434
# [1049]	valid_0's multi_logloss: 0.0243257
# [1050]	valid_0's multi_logloss: 0.0243374
# [1051]	valid_0's multi_logloss: 0.0243274
# [1052]	valid_0's multi_logloss: 0.0243196
# [1053]	valid_0's multi_logloss: 0.0243391
# [1054]	valid_0's multi_logloss: 0.0243324
# [1055]	valid_0's multi_logloss: 0.0243236
# [1056]	valid_0's multi_logloss: 0.024332
# [1057]	valid_0's multi_logloss: 0.0242927
# [1058]	valid_0's multi_logloss: 0.0243116
# [1059]	valid_0's multi_logloss: 0.0243108
# [1060]	valid_0's multi_logloss: 0.0243227
# [1061]	valid_0's multi_logloss: 0.0243024
# [1062]	valid_0's multi_logloss: 0.0242829
# [1063]	valid_0's multi_logloss: 0.0243085
# [1064]	valid_0's multi_logloss: 0.0243034
# [1065]	valid_0's multi_logloss: 0.0243006
# [1066]	valid_0's multi_logloss: 0.0243022
# [1067]	valid_0's multi_logloss: 0.0243069
# [1068]	valid_0's multi_logloss: 0.0243303
# [1069]	valid_0's multi_logloss: 0.0243176
# [1070]	valid_0's multi_logloss: 0.0242945
# [1071]	valid_0's multi_logloss: 0.0242544
# [1072]	valid_0's multi_logloss: 0.0242676
# [1073]	valid_0's multi_logloss: 0.0242428
# [1074]	valid_0's multi_logloss: 0.0242461
# [1075]	valid_0's multi_logloss: 0.0242273
# [1076]	valid_0's multi_logloss: 0.0242506
# [1077]	valid_0's multi_logloss: 0.0242422
# [1078]	valid_0's multi_logloss: 0.02426
# [1079]	valid_0's multi_logloss: 0.0242819
# [1080]	valid_0's multi_logloss: 0.0242665
# [1081]	valid_0's multi_logloss: 0.0242989
# [1082]	valid_0's multi_logloss: 0.0243101
# [1083]	valid_0's multi_logloss: 0.0243139
# [1084]	valid_0's multi_logloss: 0.0243098
# [1085]	valid_0's multi_logloss: 0.0243053
# [1086]	valid_0's multi_logloss: 0.0242981
# [1087]	valid_0's multi_logloss: 0.0242985
# [1088]	valid_0's multi_logloss: 0.0242865
# [1089]	valid_0's multi_logloss: 0.0242749
# [1090]	valid_0's multi_logloss: 0.0242906
# [1091]	valid_0's multi_logloss: 0.0243021
# [1092]	valid_0's multi_logloss: 0.0243033
# [1093]	valid_0's multi_logloss: 0.0243029
# [1094]	valid_0's multi_logloss: 0.0243039
# [1095]	valid_0's multi_logloss: 0.02431
# [1096]	valid_0's multi_logloss: 0.0243303
# [1097]	valid_0's multi_logloss: 0.0243213
# [1098]	valid_0's multi_logloss: 0.0243132
# [1099]	valid_0's multi_logloss: 0.0243309
# [1100]	valid_0's multi_logloss: 0.0243039
# [1101]	valid_0's multi_logloss: 0.0242855
# [1102]	valid_0's multi_logloss: 0.0242651
# [1103]	valid_0's multi_logloss: 0.024299
# [1104]	valid_0's multi_logloss: 0.0242989
# [1105]	valid_0's multi_logloss: 0.0242696
# [1106]	valid_0's multi_logloss: 0.0242564
# [1107]	valid_0's multi_logloss: 0.0242774
# [1108]	valid_0's multi_logloss: 0.0242726
# [1109]	valid_0's multi_logloss: 0.0242586
# [1110]	valid_0's multi_logloss: 0.024273
# [1111]	valid_0's multi_logloss: 0.0242688
# [1112]	valid_0's multi_logloss: 0.0242794
# [1113]	valid_0's multi_logloss: 0.0242809
# [1114]	valid_0's multi_logloss: 0.024286
# [1115]	valid_0's multi_logloss: 0.0242854
# [1116]	valid_0's multi_logloss: 0.0242828
# [1117]	valid_0's multi_logloss: 0.0242563
# [1118]	valid_0's multi_logloss: 0.0242495
# [1119]	valid_0's multi_logloss: 0.0242481
# [1120]	valid_0's multi_logloss: 0.0242568
# [1121]	valid_0's multi_logloss: 0.0242219
# [1122]	valid_0's multi_logloss: 0.0242712
# [1123]	valid_0's multi_logloss: 0.0242774
# [1124]	valid_0's multi_logloss: 0.0242982
# [1125]	valid_0's multi_logloss: 0.0242979
# [1126]	valid_0's multi_logloss: 0.0242847
# [1127]	valid_0's multi_logloss: 0.0242756
# [1128]	valid_0's multi_logloss: 0.0242621
# [1129]	valid_0's multi_logloss: 0.024262
# [1130]	valid_0's multi_logloss: 0.0242524
# [1131]	valid_0's multi_logloss: 0.0242657
# [1132]	valid_0's multi_logloss: 0.0242749
# [1133]	valid_0's multi_logloss: 0.0242869
# [1134]	valid_0's multi_logloss: 0.0242734
# [1135]	valid_0's multi_logloss: 0.0242603
# [1136]	valid_0's multi_logloss: 0.0242799
# [1137]	valid_0's multi_logloss: 0.0242535
# [1138]	valid_0's multi_logloss: 0.0242494
# [1139]	valid_0's multi_logloss: 0.0242484
# [1140]	valid_0's multi_logloss: 0.0242495
# [1141]	valid_0's multi_logloss: 0.0242611
# [1142]	valid_0's multi_logloss: 0.0242339
# [1143]	valid_0's multi_logloss: 0.0241996
# [1144]	valid_0's multi_logloss: 0.0241801
# [1145]	valid_0's multi_logloss: 0.0241533
# [1146]	valid_0's multi_logloss: 0.0241512
# [1147]	valid_0's multi_logloss: 0.0241512
# [1148]	valid_0's multi_logloss: 0.024142
# [1149]	valid_0's multi_logloss: 0.0241282
# [1150]	valid_0's multi_logloss: 0.0240977
# [1151]	valid_0's multi_logloss: 0.024133
# [1152]	valid_0's multi_logloss: 0.0241401
# [1153]	valid_0's multi_logloss: 0.0241311
# [1154]	valid_0's multi_logloss: 0.0241597
# [1155]	valid_0's multi_logloss: 0.02418
# [1156]	valid_0's multi_logloss: 0.0241775
# [1157]	valid_0's multi_logloss: 0.0241731
# [1158]	valid_0's multi_logloss: 0.0241686
# [1159]	valid_0's multi_logloss: 0.0241698
# [1160]	valid_0's multi_logloss: 0.0241715
# [1161]	valid_0's multi_logloss: 0.0241553
# [1162]	valid_0's multi_logloss: 0.0241556
# [1163]	valid_0's multi_logloss: 0.0241845
# [1164]	valid_0's multi_logloss: 0.0241877
# [1165]	valid_0's multi_logloss: 0.0241696
# [1166]	valid_0's multi_logloss: 0.0241731
# [1167]	valid_0's multi_logloss: 0.0241786
# [1168]	valid_0's multi_logloss: 0.0241858
# [1169]	valid_0's multi_logloss: 0.0242044
# [1170]	valid_0's multi_logloss: 0.0241966
# [1171]	valid_0's multi_logloss: 0.0242002
# [1172]	valid_0's multi_logloss: 0.0241639
# [1173]	valid_0's multi_logloss: 0.0241368
# [1174]	valid_0's multi_logloss: 0.0241574
# [1175]	valid_0's multi_logloss: 0.0241641
# [1176]	valid_0's multi_logloss: 0.024175
# [1177]	valid_0's multi_logloss: 0.0241666
# [1178]	valid_0's multi_logloss: 0.0241771
# [1179]	valid_0's multi_logloss: 0.0241647
# [1180]	valid_0's multi_logloss: 0.0241617
# [1181]	valid_0's multi_logloss: 0.0241455
# [1182]	valid_0's multi_logloss: 0.0241232
# [1183]	valid_0's multi_logloss: 0.0241148
# [1184]	valid_0's multi_logloss: 0.0241277
# [1185]	valid_0's multi_logloss: 0.0241572
# [1186]	valid_0's multi_logloss: 0.0241424
# [1187]	valid_0's multi_logloss: 0.0241787
# [1188]	valid_0's multi_logloss: 0.024174
# [1189]	valid_0's multi_logloss: 0.0241665
# [1190]	valid_0's multi_logloss: 0.0241657
# [1191]	valid_0's multi_logloss: 0.024156
# [1192]	valid_0's multi_logloss: 0.0241731
# [1193]	valid_0's multi_logloss: 0.0241643
# [1194]	valid_0's multi_logloss: 0.0241816
# [1195]	valid_0's multi_logloss: 0.0242004
# [1196]	valid_0's multi_logloss: 0.0241817
# [1197]	valid_0's multi_logloss: 0.0241677
# [1198]	valid_0's multi_logloss: 0.0241921
# [1199]	valid_0's multi_logloss: 0.0241804
# [1200]	valid_0's multi_logloss: 0.0241767
# [1201]	valid_0's multi_logloss: 0.0241601
# [1202]	valid_0's multi_logloss: 0.0241603
# [1203]	valid_0's multi_logloss: 0.0241607
# [1204]	valid_0's multi_logloss: 0.0241436
# [1205]	valid_0's multi_logloss: 0.0241555
# [1206]	valid_0's multi_logloss: 0.0241395
# [1207]	valid_0's multi_logloss: 0.0241454
# [1208]	valid_0's multi_logloss: 0.024139
# [1209]	valid_0's multi_logloss: 0.0241602
# [1210]	valid_0's multi_logloss: 0.0241757
# [1211]	valid_0's multi_logloss: 0.0241839
# [1212]	valid_0's multi_logloss: 0.0241783
# [1213]	valid_0's multi_logloss: 0.0241531
# [1214]	valid_0's multi_logloss: 0.0241292
# [1215]	valid_0's multi_logloss: 0.0241553
# [1216]	valid_0's multi_logloss: 0.0241468
# [1217]	valid_0's multi_logloss: 0.0241568
# [1218]	valid_0's multi_logloss: 0.0241723
# [1219]	valid_0's multi_logloss: 0.024164
# [1220]	valid_0's multi_logloss: 0.0241618
# [1221]	valid_0's multi_logloss: 0.0241652
# [1222]	valid_0's multi_logloss: 0.0241625
# [1223]	valid_0's multi_logloss: 0.0241357
# [1224]	valid_0's multi_logloss: 0.0241461
# [1225]	valid_0's multi_logloss: 0.0241519
# [1226]	valid_0's multi_logloss: 0.0241231
# [1227]	valid_0's multi_logloss: 0.0241366
# [1228]	valid_0's multi_logloss: 0.0241371
# [1229]	valid_0's multi_logloss: 0.0241346
# [1230]	valid_0's multi_logloss: 0.0241291
# [1231]	valid_0's multi_logloss: 0.0241222
# [1232]	valid_0's multi_logloss: 0.0241314
# [1233]	valid_0's multi_logloss: 0.0241173
# [1234]	valid_0's multi_logloss: 0.0241379
# [1235]	valid_0's multi_logloss: 0.0241422
# [1236]	valid_0's multi_logloss: 0.0241376
# [1237]	valid_0's multi_logloss: 0.0241594
# [1238]	valid_0's multi_logloss: 0.0241711
# [1239]	valid_0's multi_logloss: 0.0241687
# [1240]	valid_0's multi_logloss: 0.0241644
# [1241]	valid_0's multi_logloss: 0.024161
# [1242]	valid_0's multi_logloss: 0.0242034
# [1243]	valid_0's multi_logloss: 0.0241899
# [1244]	valid_0's multi_logloss: 0.0241972
# [1245]	valid_0's multi_logloss: 0.0242066
# [1246]	valid_0's multi_logloss: 0.0242201
# [1247]	valid_0's multi_logloss: 0.0242298
# [1248]	valid_0's multi_logloss: 0.0242111
# [1249]	valid_0's multi_logloss: 0.024199
# [1250]	valid_0's multi_logloss: 0.0241933
# [1251]	valid_0's multi_logloss: 0.0241738
# [1252]	valid_0's multi_logloss: 0.0242038
# [1253]	valid_0's multi_logloss: 0.0241905
# [1254]	valid_0's multi_logloss: 0.024177
# [1255]	valid_0's multi_logloss: 0.0241717
# [1256]	valid_0's multi_logloss: 0.0241553
# [1257]	valid_0's multi_logloss: 0.0241369
# [1258]	valid_0's multi_logloss: 0.0241661
# [1259]	valid_0's multi_logloss: 0.0241814
# [1260]	valid_0's multi_logloss: 0.0241552
# [1261]	valid_0's multi_logloss: 0.02414
# [1262]	valid_0's multi_logloss: 0.0241253
# [1263]	valid_0's multi_logloss: 0.0241094
# [1264]	valid_0's multi_logloss: 0.0241292
# [1265]	valid_0's multi_logloss: 0.0241109
# [1266]	valid_0's multi_logloss: 0.0241352
# [1267]	valid_0's multi_logloss: 0.0241354
# [1268]	valid_0's multi_logloss: 0.0241066
# [1269]	valid_0's multi_logloss: 0.0240866
# [1270]	valid_0's multi_logloss: 0.0240695
# [1271]	valid_0's multi_logloss: 0.0241039
# [1272]	valid_0's multi_logloss: 0.0240784
# [1273]	valid_0's multi_logloss: 0.0240895
# [1274]	valid_0's multi_logloss: 0.0240951
# [1275]	valid_0's multi_logloss: 0.0240782
# [1276]	valid_0's multi_logloss: 0.0240885
# [1277]	valid_0's multi_logloss: 0.0240796
# [1278]	valid_0's multi_logloss: 0.0241
# [1279]	valid_0's multi_logloss: 0.0241192
# [1280]	valid_0's multi_logloss: 0.0241089
# [1281]	valid_0's multi_logloss: 0.0240951
# [1282]	valid_0's multi_logloss: 0.0240864
# [1283]	valid_0's multi_logloss: 0.0241058
# [1284]	valid_0's multi_logloss: 0.0241277
# [1285]	valid_0's multi_logloss: 0.0241407
# [1286]	valid_0's multi_logloss: 0.0241441
# [1287]	valid_0's multi_logloss: 0.024164
# [1288]	valid_0's multi_logloss: 0.0241477
# [1289]	valid_0's multi_logloss: 0.0241538
# [1290]	valid_0's multi_logloss: 0.0241652
# [1291]	valid_0's multi_logloss: 0.024186
# [1292]	valid_0's multi_logloss: 0.0241785
# [1293]	valid_0's multi_logloss: 0.0241927
# [1294]	valid_0's multi_logloss: 0.0241851
# [1295]	valid_0's multi_logloss: 0.0241835
# [1296]	valid_0's multi_logloss: 0.0242041
# [1297]	valid_0's multi_logloss: 0.0242076
# [1298]	valid_0's multi_logloss: 0.0242163
# [1299]	valid_0's multi_logloss: 0.0242067
# [1300]	valid_0's multi_logloss: 0.0242639
# [1301]	valid_0's multi_logloss: 0.024265
# [1302]	valid_0's multi_logloss: 0.0242543
# [1303]	valid_0's multi_logloss: 0.0242681
# [1304]	valid_0's multi_logloss: 0.024255
# [1305]	valid_0's multi_logloss: 0.0242473
# [1306]	valid_0's multi_logloss: 0.0242216
# [1307]	valid_0's multi_logloss: 0.0242175
# [1308]	valid_0's multi_logloss: 0.024205
# [1309]	valid_0's multi_logloss: 0.0242
# [1310]	valid_0's multi_logloss: 0.0242135
# [1311]	valid_0's multi_logloss: 0.0242028
# [1312]	valid_0's multi_logloss: 0.0241923
# [1313]	valid_0's multi_logloss: 0.0242012
# [1314]	valid_0's multi_logloss: 0.0242172
# [1315]	valid_0's multi_logloss: 0.024239
# [1316]	valid_0's multi_logloss: 0.0242562
# [1317]	valid_0's multi_logloss: 0.0242868
# [1318]	valid_0's multi_logloss: 0.0242984
# [1319]	valid_0's multi_logloss: 0.0242789
# [1320]	valid_0's multi_logloss: 0.0242732
# [1321]	valid_0's multi_logloss: 0.0242812
# [1322]	valid_0's multi_logloss: 0.0242748
# [1323]	valid_0's multi_logloss: 0.0242754
# [1324]	valid_0's multi_logloss: 0.02427
# [1325]	valid_0's multi_logloss: 0.024295
# [1326]	valid_0's multi_logloss: 0.0242992
# [1327]	valid_0's multi_logloss: 0.0242923
# [1328]	valid_0's multi_logloss: 0.0243031
# [1329]	valid_0's multi_logloss: 0.0242955
# [1330]	valid_0's multi_logloss: 0.0242939
# [1331]	valid_0's multi_logloss: 0.0243006
# [1332]	valid_0's multi_logloss: 0.024315
# [1333]	valid_0's multi_logloss: 0.0242979
# [1334]	valid_0's multi_logloss: 0.0243008
# [1335]	valid_0's multi_logloss: 0.0242755
# [1336]	valid_0's multi_logloss: 0.0242821
# [1337]	valid_0's multi_logloss: 0.0242501
# [1338]	valid_0's multi_logloss: 0.0242403
# [1339]	valid_0's multi_logloss: 0.0242448
# [1340]	valid_0's multi_logloss: 0.0242396
# [1341]	valid_0's multi_logloss: 0.0242499
# [1342]	valid_0's multi_logloss: 0.0242552
# [1343]	valid_0's multi_logloss: 0.0242678
# [1344]	valid_0's multi_logloss: 0.0242834
# [1345]	valid_0's multi_logloss: 0.0242731
# [1346]	valid_0's multi_logloss: 0.0242665
# [1347]	valid_0's multi_logloss: 0.0242704
# [1348]	valid_0's multi_logloss: 0.0242617
# [1349]	valid_0's multi_logloss: 0.0243006
# [1350]	valid_0's multi_logloss: 0.0242979
# [1351]	valid_0's multi_logloss: 0.0242693
# [1352]	valid_0's multi_logloss: 0.0242729
# [1353]	valid_0's multi_logloss: 0.0242894
# [1354]	valid_0's multi_logloss: 0.0242944
# [1355]	valid_0's multi_logloss: 0.0243088
# [1356]	valid_0's multi_logloss: 0.0243062
# [1357]	valid_0's multi_logloss: 0.0243186
# [1358]	valid_0's multi_logloss: 0.024327
# [1359]	valid_0's multi_logloss: 0.0243435
# [1360]	valid_0's multi_logloss: 0.0243525
# [1361]	valid_0's multi_logloss: 0.0243681
# [1362]	valid_0's multi_logloss: 0.0243646
# [1363]	valid_0's multi_logloss: 0.0243684
# [1364]	valid_0's multi_logloss: 0.0243787
# [1365]	valid_0's multi_logloss: 0.0243963
# [1366]	valid_0's multi_logloss: 0.0244173
# [1367]	valid_0's multi_logloss: 0.0244265
# [1368]	valid_0's multi_logloss: 0.024426
# [1369]	valid_0's multi_logloss: 0.0244249
# [1370]	valid_0's multi_logloss: 0.0244199
# [1371]	valid_0's multi_logloss: 0.0244417
# [1372]	valid_0's multi_logloss: 0.0244298
# [1373]	valid_0's multi_logloss: 0.024414
# [1374]	valid_0's multi_logloss: 0.0243995
# [1375]	valid_0's multi_logloss: 0.0244237
# [1376]	valid_0's multi_logloss: 0.0244239
# [1377]	valid_0's multi_logloss: 0.0244274
# [1378]	valid_0's multi_logloss: 0.0244302
# [1379]	valid_0's multi_logloss: 0.0244214
# [1380]	valid_0's multi_logloss: 0.024428
# [1381]	valid_0's multi_logloss: 0.0244162
# [1382]	valid_0's multi_logloss: 0.0244241
# [1383]	valid_0's multi_logloss: 0.024433
# [1384]	valid_0's multi_logloss: 0.024419
# [1385]	valid_0's multi_logloss: 0.0243942
# [1386]	valid_0's multi_logloss: 0.0244194
# [1387]	valid_0's multi_logloss: 0.0244201
# [1388]	valid_0's multi_logloss: 0.0244241
# [1389]	valid_0's multi_logloss: 0.0243996
# [1390]	valid_0's multi_logloss: 0.0243885
# [1391]	valid_0's multi_logloss: 0.0243973
# [1392]	valid_0's multi_logloss: 0.0244024
# [1393]	valid_0's multi_logloss: 0.0243955
# [1394]	valid_0's multi_logloss: 0.0244103
# [1395]	valid_0's multi_logloss: 0.024411
# [1396]	valid_0's multi_logloss: 0.0244185
# [1397]	valid_0's multi_logloss: 0.0244584
# [1398]	valid_0's multi_logloss: 0.0244385
# [1399]	valid_0's multi_logloss: 0.0244126
# [1400]	valid_0's multi_logloss: 0.024433
# [1401]	valid_0's multi_logloss: 0.0243815
# [1402]	valid_0's multi_logloss: 0.0243766
# [1403]	valid_0's multi_logloss: 0.0243855
# [1404]	valid_0's multi_logloss: 0.0244008
# [1405]	valid_0's multi_logloss: 0.0243974
# [1406]	valid_0's multi_logloss: 0.0243975
# [1407]	valid_0's multi_logloss: 0.0244047
# [1408]	valid_0's multi_logloss: 0.0243969
# [1409]	valid_0's multi_logloss: 0.0243922
# [1410]	valid_0's multi_logloss: 0.0243979
# [1411]	valid_0's multi_logloss: 0.0244003
# [1412]	valid_0's multi_logloss: 0.0244093
# [1413]	valid_0's multi_logloss: 0.0244395
# [1414]	valid_0's multi_logloss: 0.0244448
# [1415]	valid_0's multi_logloss: 0.0244527
# [1416]	valid_0's multi_logloss: 0.0244252
# [1417]	valid_0's multi_logloss: 0.0244467
# [1418]	valid_0's multi_logloss: 0.0244478
# [1419]	valid_0's multi_logloss: 0.0244585
# [1420]	valid_0's multi_logloss: 0.0244505
# [1421]	valid_0's multi_logloss: 0.0244724
# [1422]	valid_0's multi_logloss: 0.0244619
# [1423]	valid_0's multi_logloss: 0.0244532
# [1424]	valid_0's multi_logloss: 0.0244431
# [1425]	valid_0's multi_logloss: 0.0244516
# [1426]	valid_0's multi_logloss: 0.024462
# [1427]	valid_0's multi_logloss: 0.024458
# [1428]	valid_0's multi_logloss: 0.0244611
# [1429]	valid_0's multi_logloss: 0.024452
# [1430]	valid_0's multi_logloss: 0.0244527
# [1431]	valid_0's multi_logloss: 0.0244956
# [1432]	valid_0's multi_logloss: 0.0245052
# [1433]	valid_0's multi_logloss: 0.024492
# [1434]	valid_0's multi_logloss: 0.0244887
# [1435]	valid_0's multi_logloss: 0.0245085
# [1436]	valid_0's multi_logloss: 0.024494
# [1437]	valid_0's multi_logloss: 0.0244955
# [1438]	valid_0's multi_logloss: 0.0245055
# [1439]	valid_0's multi_logloss: 0.024524
# [1440]	valid_0's multi_logloss: 0.0245447
# [1441]	valid_0's multi_logloss: 0.0245617
# [1442]	valid_0's multi_logloss: 0.0245554
# [1443]	valid_0's multi_logloss: 0.0245743
# [1444]	valid_0's multi_logloss: 0.0245648
# [1445]	valid_0's multi_logloss: 0.0245941
# [1446]	valid_0's multi_logloss: 0.024588
# [1447]	valid_0's multi_logloss: 0.0245876
# [1448]	valid_0's multi_logloss: 0.0245983
# [1449]	valid_0's multi_logloss: 0.0246243
# [1450]	valid_0's multi_logloss: 0.0246486
# [1451]	valid_0's multi_logloss: 0.0246602
# [1452]	valid_0's multi_logloss: 0.024645
# [1453]	valid_0's multi_logloss: 0.0246582
# [1454]	valid_0's multi_logloss: 0.0246721
# [1455]	valid_0's multi_logloss: 0.0246869
# [1456]	valid_0's multi_logloss: 0.024707
# [1457]	valid_0's multi_logloss: 0.0246948
# [1458]	valid_0's multi_logloss: 0.0246989
# [1459]	valid_0's multi_logloss: 0.0246882
# [1460]	valid_0's multi_logloss: 0.024665
# [1461]	valid_0's multi_logloss: 0.0246941
# [1462]	valid_0's multi_logloss: 0.024673
# [1463]	valid_0's multi_logloss: 0.0246939
# [1464]	valid_0's multi_logloss: 0.0246679
# [1465]	valid_0's multi_logloss: 0.024653
# [1466]	valid_0's multi_logloss: 0.0246325
# [1467]	valid_0's multi_logloss: 0.0246407
# [1468]	valid_0's multi_logloss: 0.0246397
# [1469]	valid_0's multi_logloss: 0.0246243
# [1470]	valid_0's multi_logloss: 0.0246325
# [1471]	valid_0's multi_logloss: 0.0246606
# [1472]	valid_0's multi_logloss: 0.024661
# [1473]	valid_0's multi_logloss: 0.0246629
# [1474]	valid_0's multi_logloss: 0.0246473
# [1475]	valid_0's multi_logloss: 0.0246609
# [1476]	valid_0's multi_logloss: 0.0246701
# [1477]	valid_0's multi_logloss: 0.0246843
# [1478]	valid_0's multi_logloss: 0.0246909
# [1479]	valid_0's multi_logloss: 0.0247172
# [1480]	valid_0's multi_logloss: 0.0247185
# [1481]	valid_0's multi_logloss: 0.0247239
# [1482]	valid_0's multi_logloss: 0.024735
# [1483]	valid_0's multi_logloss: 0.0247216
# [1484]	valid_0's multi_logloss: 0.0247124
# [1485]	valid_0's multi_logloss: 0.0247011
# [1486]	valid_0's multi_logloss: 0.0247011
# [1487]	valid_0's multi_logloss: 0.0247074
# [1488]	valid_0's multi_logloss: 0.0247043
# [1489]	valid_0's multi_logloss: 0.0247272
# [1490]	valid_0's multi_logloss: 0.0247304
# [1491]	valid_0's multi_logloss: 0.0247469
# [1492]	valid_0's multi_logloss: 0.0247603
# [1493]	valid_0's multi_logloss: 0.0247548
# [1494]	valid_0's multi_logloss: 0.0247989
# [1495]	valid_0's multi_logloss: 0.0247733
# [1496]	valid_0's multi_logloss: 0.0247728
# [1497]	valid_0's multi_logloss: 0.0247622
# [1498]	valid_0's multi_logloss: 0.024787
# [1499]	valid_0's multi_logloss: 0.0247737
# [1500]	valid_0's multi_logloss: 0.0247807
# [1501]	valid_0's multi_logloss: 0.0247553
# [1502]	valid_0's multi_logloss: 0.0247662
# [1503]	valid_0's multi_logloss: 0.0247604
# [1504]	valid_0's multi_logloss: 0.0247543
# [1505]	valid_0's multi_logloss: 0.0247332
# [1506]	valid_0's multi_logloss: 0.0247352
# [1507]	valid_0's multi_logloss: 0.0246927
# [1508]	valid_0's multi_logloss: 0.0247066
# [1509]	valid_0's multi_logloss: 0.0247056
# [1510]	valid_0's multi_logloss: 0.0247418
# [1511]	valid_0's multi_logloss: 0.02476
# [1512]	valid_0's multi_logloss: 0.0247684
# [1513]	valid_0's multi_logloss: 0.024767
# [1514]	valid_0's multi_logloss: 0.024768
# [1515]	valid_0's multi_logloss: 0.0247669
# [1516]	valid_0's multi_logloss: 0.0247754
# [1517]	valid_0's multi_logloss: 0.0247552
# [1518]	valid_0's multi_logloss: 0.0247593
# [1519]	valid_0's multi_logloss: 0.0247845
# [1520]	valid_0's multi_logloss: 0.0248131
# [1521]	valid_0's multi_logloss: 0.0248021
# [1522]	valid_0's multi_logloss: 0.024793
# [1523]	valid_0's multi_logloss: 0.0248173
# [1524]	valid_0's multi_logloss: 0.0248162
# [1525]	valid_0's multi_logloss: 0.0248309
# [1526]	valid_0's multi_logloss: 0.024848
# [1527]	valid_0's multi_logloss: 0.0248564
# [1528]	valid_0's multi_logloss: 0.024864
# [1529]	valid_0's multi_logloss: 0.024868
# [1530]	valid_0's multi_logloss: 0.0248689
# [1531]	valid_0's multi_logloss: 0.0248677
# [1532]	valid_0's multi_logloss: 0.0248487
# [1533]	valid_0's multi_logloss: 0.0248711
# [1534]	valid_0's multi_logloss: 0.0249082
# [1535]	valid_0's multi_logloss: 0.0248901
# [1536]	valid_0's multi_logloss: 0.0248731
# [1537]	valid_0's multi_logloss: 0.0248595
# [1538]	valid_0's multi_logloss: 0.0248655
# [1539]	valid_0's multi_logloss: 0.0248409
# [1540]	valid_0's multi_logloss: 0.024849
# [1541]	valid_0's multi_logloss: 0.0248331
# [1542]	valid_0's multi_logloss: 0.024857
# [1543]	valid_0's multi_logloss: 0.0248562
# [1544]	valid_0's multi_logloss: 0.0248556
# [1545]	valid_0's multi_logloss: 0.0248495
# [1546]	valid_0's multi_logloss: 0.0248487
# [1547]	valid_0's multi_logloss: 0.0248797
# [1548]	valid_0's multi_logloss: 0.0248824
# [1549]	valid_0's multi_logloss: 0.0248968
# [1550]	valid_0's multi_logloss: 0.0249136
# [1551]	valid_0's multi_logloss: 0.0249115
# [1552]	valid_0's multi_logloss: 0.0249149
# [1553]	valid_0's multi_logloss: 0.0249124
# [1554]	valid_0's multi_logloss: 0.0249038
# [1555]	valid_0's multi_logloss: 0.0249085
# [1556]	valid_0's multi_logloss: 0.0249206
# [1557]	valid_0's multi_logloss: 0.0249095
# [1558]	valid_0's multi_logloss: 0.0249238
# [1559]	valid_0's multi_logloss: 0.0249266
# [1560]	valid_0's multi_logloss: 0.0249226
# [1561]	valid_0's multi_logloss: 0.0249439
# [1562]	valid_0's multi_logloss: 0.0249229
# [1563]	valid_0's multi_logloss: 0.0249198
# [1564]	valid_0's multi_logloss: 0.0249133
# [1565]	valid_0's multi_logloss: 0.0249007
# [1566]	valid_0's multi_logloss: 0.0248919
# [1567]	valid_0's multi_logloss: 0.0248943
# [1568]	valid_0's multi_logloss: 0.0249121
# [1569]	valid_0's multi_logloss: 0.0248963
# [1570]	valid_0's multi_logloss: 0.0248841
# Early stopping, best iteration is:
# [1270]	valid_0's multi_logloss: 0.0240695
# Fold n°7 on LGBM. AUC : 1.000 | Accuracy : 99.0%
#
# [1]	valid_0's multi_logloss: 1.77536
# Training until validation scores don't improve for 300 rounds.
# [2]	valid_0's multi_logloss: 1.65435
# [3]	valid_0's multi_logloss: 1.55073
# [4]	valid_0's multi_logloss: 1.45926
# [5]	valid_0's multi_logloss: 1.37893
# [6]	valid_0's multi_logloss: 1.30682
# [7]	valid_0's multi_logloss: 1.24128
# [8]	valid_0's multi_logloss: 1.18092
# [9]	valid_0's multi_logloss: 1.12636
# [10]	valid_0's multi_logloss: 1.07603
# [11]	valid_0's multi_logloss: 1.02928
# [12]	valid_0's multi_logloss: 0.986077
# [13]	valid_0's multi_logloss: 0.945893
# [14]	valid_0's multi_logloss: 0.908718
# [15]	valid_0's multi_logloss: 0.87378
# [16]	valid_0's multi_logloss: 0.841023
# [17]	valid_0's multi_logloss: 0.810629
# [18]	valid_0's multi_logloss: 0.782241
# [19]	valid_0's multi_logloss: 0.755772
# [20]	valid_0's multi_logloss: 0.730033
# [21]	valid_0's multi_logloss: 0.706235
# [22]	valid_0's multi_logloss: 0.683314
# [23]	valid_0's multi_logloss: 0.662321
# [24]	valid_0's multi_logloss: 0.641906
# [25]	valid_0's multi_logloss: 0.622532
# [26]	valid_0's multi_logloss: 0.603671
# [27]	valid_0's multi_logloss: 0.586451
# [28]	valid_0's multi_logloss: 0.56986
# [29]	valid_0's multi_logloss: 0.554302
# [30]	valid_0's multi_logloss: 0.539445
# [31]	valid_0's multi_logloss: 0.525035
# [32]	valid_0's multi_logloss: 0.511548
# [33]	valid_0's multi_logloss: 0.498391
# [34]	valid_0's multi_logloss: 0.486117
# [35]	valid_0's multi_logloss: 0.474019
# [36]	valid_0's multi_logloss: 0.462541
# [37]	valid_0's multi_logloss: 0.451267
# [38]	valid_0's multi_logloss: 0.440695
# [39]	valid_0's multi_logloss: 0.430479
# [40]	valid_0's multi_logloss: 0.420648
# [41]	valid_0's multi_logloss: 0.411279
# [42]	valid_0's multi_logloss: 0.402289
# [43]	valid_0's multi_logloss: 0.393582
# [44]	valid_0's multi_logloss: 0.385137
# [45]	valid_0's multi_logloss: 0.376917
# [46]	valid_0's multi_logloss: 0.36924
# [47]	valid_0's multi_logloss: 0.361899
# [48]	valid_0's multi_logloss: 0.354503
# [49]	valid_0's multi_logloss: 0.347537
# [50]	valid_0's multi_logloss: 0.340902
# [51]	valid_0's multi_logloss: 0.33428
# [52]	valid_0's multi_logloss: 0.327986
# [53]	valid_0's multi_logloss: 0.321816
# [54]	valid_0's multi_logloss: 0.315815
# [55]	valid_0's multi_logloss: 0.310161
# [56]	valid_0's multi_logloss: 0.304719
# [57]	valid_0's multi_logloss: 0.299203
# [58]	valid_0's multi_logloss: 0.293949
# [59]	valid_0's multi_logloss: 0.288908
# [60]	valid_0's multi_logloss: 0.283963
# [61]	valid_0's multi_logloss: 0.279274
# [62]	valid_0's multi_logloss: 0.274579
# [63]	valid_0's multi_logloss: 0.270211
# [64]	valid_0's multi_logloss: 0.265712
# [65]	valid_0's multi_logloss: 0.261527
# [66]	valid_0's multi_logloss: 0.25737
# [67]	valid_0's multi_logloss: 0.253317
# [68]	valid_0's multi_logloss: 0.249377
# [69]	valid_0's multi_logloss: 0.245586
# [70]	valid_0's multi_logloss: 0.24192
# [71]	valid_0's multi_logloss: 0.238248
# [72]	valid_0's multi_logloss: 0.234649
# [73]	valid_0's multi_logloss: 0.231284
# [74]	valid_0's multi_logloss: 0.227959
# [75]	valid_0's multi_logloss: 0.224695
# [76]	valid_0's multi_logloss: 0.221466
# [77]	valid_0's multi_logloss: 0.218321
# [78]	valid_0's multi_logloss: 0.215319
# [79]	valid_0's multi_logloss: 0.212292
# [80]	valid_0's multi_logloss: 0.20932
# [81]	valid_0's multi_logloss: 0.206363
# [82]	valid_0's multi_logloss: 0.203545
# [83]	valid_0's multi_logloss: 0.201039
# [84]	valid_0's multi_logloss: 0.198289
# [85]	valid_0's multi_logloss: 0.195552
# [86]	valid_0's multi_logloss: 0.192945
# [87]	valid_0's multi_logloss: 0.190449
# [88]	valid_0's multi_logloss: 0.188008
# [89]	valid_0's multi_logloss: 0.185801
# [90]	valid_0's multi_logloss: 0.183399
# [91]	valid_0's multi_logloss: 0.181149
# [92]	valid_0's multi_logloss: 0.178953
# [93]	valid_0's multi_logloss: 0.176828
# [94]	valid_0's multi_logloss: 0.174629
# [95]	valid_0's multi_logloss: 0.172505
# [96]	valid_0's multi_logloss: 0.170474
# [97]	valid_0's multi_logloss: 0.168434
# [98]	valid_0's multi_logloss: 0.166505
# [99]	valid_0's multi_logloss: 0.16458
# [100]	valid_0's multi_logloss: 0.162715
# [101]	valid_0's multi_logloss: 0.160887
# [102]	valid_0's multi_logloss: 0.159378
# [103]	valid_0's multi_logloss: 0.157625
# [104]	valid_0's multi_logloss: 0.155837
# [105]	valid_0's multi_logloss: 0.15421
# [106]	valid_0's multi_logloss: 0.152614
# [107]	valid_0's multi_logloss: 0.151122
# [108]	valid_0's multi_logloss: 0.149472
# [109]	valid_0's multi_logloss: 0.147885
# [110]	valid_0's multi_logloss: 0.146176
# [111]	valid_0's multi_logloss: 0.144819
# [112]	valid_0's multi_logloss: 0.143266
# [113]	valid_0's multi_logloss: 0.141921
# [114]	valid_0's multi_logloss: 0.14058
# [115]	valid_0's multi_logloss: 0.139088
# [116]	valid_0's multi_logloss: 0.137949
# [117]	valid_0's multi_logloss: 0.136586
# [118]	valid_0's multi_logloss: 0.135271
# [119]	valid_0's multi_logloss: 0.133947
# [120]	valid_0's multi_logloss: 0.132783
# [121]	valid_0's multi_logloss: 0.131523
# [122]	valid_0's multi_logloss: 0.130405
# [123]	valid_0's multi_logloss: 0.129206
# [124]	valid_0's multi_logloss: 0.127871
# [125]	valid_0's multi_logloss: 0.12673
# [126]	valid_0's multi_logloss: 0.125564
# [127]	valid_0's multi_logloss: 0.124252
# [128]	valid_0's multi_logloss: 0.123073
# [129]	valid_0's multi_logloss: 0.121856
# [130]	valid_0's multi_logloss: 0.120821
# [131]	valid_0's multi_logloss: 0.119841
# [132]	valid_0's multi_logloss: 0.118736
# [133]	valid_0's multi_logloss: 0.117736
# [134]	valid_0's multi_logloss: 0.116739
# [135]	valid_0's multi_logloss: 0.115825
# [136]	valid_0's multi_logloss: 0.114852
# [137]	valid_0's multi_logloss: 0.113799
# [138]	valid_0's multi_logloss: 0.112869
# [139]	valid_0's multi_logloss: 0.112007
# [140]	valid_0's multi_logloss: 0.111156
# [141]	valid_0's multi_logloss: 0.110163
# [142]	valid_0's multi_logloss: 0.109299
# [143]	valid_0's multi_logloss: 0.108358
# [144]	valid_0's multi_logloss: 0.107492
# [145]	valid_0's multi_logloss: 0.106595
# [146]	valid_0's multi_logloss: 0.105766
# [147]	valid_0's multi_logloss: 0.104872
# [148]	valid_0's multi_logloss: 0.103987
# [149]	valid_0's multi_logloss: 0.10319
# [150]	valid_0's multi_logloss: 0.102389
# [151]	valid_0's multi_logloss: 0.101651
# [152]	valid_0's multi_logloss: 0.100952
# [153]	valid_0's multi_logloss: 0.100173
# [154]	valid_0's multi_logloss: 0.099421
# [155]	valid_0's multi_logloss: 0.0986229
# [156]	valid_0's multi_logloss: 0.0980147
# [157]	valid_0's multi_logloss: 0.0973324
# [158]	valid_0's multi_logloss: 0.0966235
# [159]	valid_0's multi_logloss: 0.0958759
# [160]	valid_0's multi_logloss: 0.0950692
# [161]	valid_0's multi_logloss: 0.0943869
# [162]	valid_0's multi_logloss: 0.0937158
# [163]	valid_0's multi_logloss: 0.0931238
# [164]	valid_0's multi_logloss: 0.0924533
# [165]	valid_0's multi_logloss: 0.0917317
# [166]	valid_0's multi_logloss: 0.0912245
# [167]	valid_0's multi_logloss: 0.0907255
# [168]	valid_0's multi_logloss: 0.0900848
# [169]	valid_0's multi_logloss: 0.0895165
# [170]	valid_0's multi_logloss: 0.0889156
# [171]	valid_0's multi_logloss: 0.0883101
# [172]	valid_0's multi_logloss: 0.0877005
# [173]	valid_0's multi_logloss: 0.0872849
# [174]	valid_0's multi_logloss: 0.0866746
# [175]	valid_0's multi_logloss: 0.0860888
# [176]	valid_0's multi_logloss: 0.0855992
# [177]	valid_0's multi_logloss: 0.0851126
# [178]	valid_0's multi_logloss: 0.0844406
# [179]	valid_0's multi_logloss: 0.0839603
# [180]	valid_0's multi_logloss: 0.0834406
# [181]	valid_0's multi_logloss: 0.0829882
# [182]	valid_0's multi_logloss: 0.0824867
# [183]	valid_0's multi_logloss: 0.0819802
# [184]	valid_0's multi_logloss: 0.081433
# [185]	valid_0's multi_logloss: 0.0809132
# [186]	valid_0's multi_logloss: 0.0804339
# [187]	valid_0's multi_logloss: 0.0799391
# [188]	valid_0's multi_logloss: 0.0795431
# [189]	valid_0's multi_logloss: 0.0790578
# [190]	valid_0's multi_logloss: 0.0785854
# [191]	valid_0's multi_logloss: 0.0781092
# [192]	valid_0's multi_logloss: 0.0777219
# [193]	valid_0's multi_logloss: 0.0773239
# [194]	valid_0's multi_logloss: 0.0768932
# [195]	valid_0's multi_logloss: 0.0764498
# [196]	valid_0's multi_logloss: 0.0760108
# [197]	valid_0's multi_logloss: 0.0756025
# [198]	valid_0's multi_logloss: 0.0752009
# [199]	valid_0's multi_logloss: 0.0747869
# [200]	valid_0's multi_logloss: 0.0744483
# [201]	valid_0's multi_logloss: 0.0740849
# [202]	valid_0's multi_logloss: 0.0736543
# [203]	valid_0's multi_logloss: 0.0732321
# [204]	valid_0's multi_logloss: 0.0729136
# [205]	valid_0's multi_logloss: 0.0724806
# [206]	valid_0's multi_logloss: 0.0721587
# [207]	valid_0's multi_logloss: 0.0718115
# [208]	valid_0's multi_logloss: 0.0714535
# [209]	valid_0's multi_logloss: 0.0710608
# [210]	valid_0's multi_logloss: 0.0707717
# [211]	valid_0's multi_logloss: 0.0703417
# [212]	valid_0's multi_logloss: 0.0700122
# [213]	valid_0's multi_logloss: 0.0696365
# [214]	valid_0's multi_logloss: 0.0692055
# [215]	valid_0's multi_logloss: 0.0688149
# [216]	valid_0's multi_logloss: 0.0684748
# [217]	valid_0's multi_logloss: 0.0681677
# [218]	valid_0's multi_logloss: 0.0678164
# [219]	valid_0's multi_logloss: 0.0675122
# [220]	valid_0's multi_logloss: 0.067189
# [221]	valid_0's multi_logloss: 0.0668794
# [222]	valid_0's multi_logloss: 0.0665275
# [223]	valid_0's multi_logloss: 0.0661966
# [224]	valid_0's multi_logloss: 0.0658769
# [225]	valid_0's multi_logloss: 0.0655622
# [226]	valid_0's multi_logloss: 0.0652621
# [227]	valid_0's multi_logloss: 0.0649588
# [228]	valid_0's multi_logloss: 0.0646476
# [229]	valid_0's multi_logloss: 0.0643187
# [230]	valid_0's multi_logloss: 0.0640259
# [231]	valid_0's multi_logloss: 0.0637354
# [232]	valid_0's multi_logloss: 0.0634583
# [233]	valid_0's multi_logloss: 0.0632013
# [234]	valid_0's multi_logloss: 0.0629474
# [235]	valid_0's multi_logloss: 0.0626911
# [236]	valid_0's multi_logloss: 0.062414
# [237]	valid_0's multi_logloss: 0.0621554
# [238]	valid_0's multi_logloss: 0.061893
# [239]	valid_0's multi_logloss: 0.0616177
# [240]	valid_0's multi_logloss: 0.0613075
# [241]	valid_0's multi_logloss: 0.0610613
# [242]	valid_0's multi_logloss: 0.0608764
# [243]	valid_0's multi_logloss: 0.0605961
# [244]	valid_0's multi_logloss: 0.0603154
# [245]	valid_0's multi_logloss: 0.0600669
# [246]	valid_0's multi_logloss: 0.0598733
# [247]	valid_0's multi_logloss: 0.0596952
# [248]	valid_0's multi_logloss: 0.0594171
# [249]	valid_0's multi_logloss: 0.0591843
# [250]	valid_0's multi_logloss: 0.0589887
# [251]	valid_0's multi_logloss: 0.0587829
# [252]	valid_0's multi_logloss: 0.0585663
# [253]	valid_0's multi_logloss: 0.0583064
# [254]	valid_0's multi_logloss: 0.0581041
# [255]	valid_0's multi_logloss: 0.057925
# [256]	valid_0's multi_logloss: 0.0577399
# [257]	valid_0's multi_logloss: 0.057494
# [258]	valid_0's multi_logloss: 0.0573295
# [259]	valid_0's multi_logloss: 0.0571172
# [260]	valid_0's multi_logloss: 0.0568435
# [261]	valid_0's multi_logloss: 0.0566517
# [262]	valid_0's multi_logloss: 0.0564415
# [263]	valid_0's multi_logloss: 0.0562324
# [264]	valid_0's multi_logloss: 0.0560668
# [265]	valid_0's multi_logloss: 0.0558913
# [266]	valid_0's multi_logloss: 0.0556826
# [267]	valid_0's multi_logloss: 0.0554691
# [268]	valid_0's multi_logloss: 0.0552377
# [269]	valid_0's multi_logloss: 0.0549573
# [270]	valid_0's multi_logloss: 0.0547941
# [271]	valid_0's multi_logloss: 0.054566
# [272]	valid_0's multi_logloss: 0.054374
# [273]	valid_0's multi_logloss: 0.0541687
# [274]	valid_0's multi_logloss: 0.0539219
# [275]	valid_0's multi_logloss: 0.0537
# [276]	valid_0's multi_logloss: 0.0535261
# [277]	valid_0's multi_logloss: 0.0533431
# [278]	valid_0's multi_logloss: 0.0531918
# [279]	valid_0's multi_logloss: 0.0530251
# [280]	valid_0's multi_logloss: 0.0528748
# [281]	valid_0's multi_logloss: 0.0527079
# [282]	valid_0's multi_logloss: 0.0525213
# [283]	valid_0's multi_logloss: 0.0523761
# [284]	valid_0's multi_logloss: 0.0522591
# [285]	valid_0's multi_logloss: 0.0521031
# [286]	valid_0's multi_logloss: 0.0519229
# [287]	valid_0's multi_logloss: 0.0517521
# [288]	valid_0's multi_logloss: 0.0515613
# [289]	valid_0's multi_logloss: 0.0514321
# [290]	valid_0's multi_logloss: 0.0512536
# [291]	valid_0's multi_logloss: 0.0510403
# [292]	valid_0's multi_logloss: 0.050835
# [293]	valid_0's multi_logloss: 0.0506661
# [294]	valid_0's multi_logloss: 0.0504662
# [295]	valid_0's multi_logloss: 0.0502697
# [296]	valid_0's multi_logloss: 0.0501379
# [297]	valid_0's multi_logloss: 0.0499928
# [298]	valid_0's multi_logloss: 0.0498454
# [299]	valid_0's multi_logloss: 0.0497213
# [300]	valid_0's multi_logloss: 0.0495558
# [301]	valid_0's multi_logloss: 0.0493766
# [302]	valid_0's multi_logloss: 0.0491766
# [303]	valid_0's multi_logloss: 0.048978
# [304]	valid_0's multi_logloss: 0.0488493
# [305]	valid_0's multi_logloss: 0.0486824
# [306]	valid_0's multi_logloss: 0.0485054
# [307]	valid_0's multi_logloss: 0.0483542
# [308]	valid_0's multi_logloss: 0.0481614
# [309]	valid_0's multi_logloss: 0.0480694
# [310]	valid_0's multi_logloss: 0.0479357
# [311]	valid_0's multi_logloss: 0.0478014
# [312]	valid_0's multi_logloss: 0.0477073
# [313]	valid_0's multi_logloss: 0.0475282
# [314]	valid_0's multi_logloss: 0.0474069
# [315]	valid_0's multi_logloss: 0.0472492
# [316]	valid_0's multi_logloss: 0.0471042
# [317]	valid_0's multi_logloss: 0.0469004
# [318]	valid_0's multi_logloss: 0.0467704
# [319]	valid_0's multi_logloss: 0.0465987
# [320]	valid_0's multi_logloss: 0.046419
# [321]	valid_0's multi_logloss: 0.0462603
# [322]	valid_0's multi_logloss: 0.0461532
# [323]	valid_0's multi_logloss: 0.0460378
# [324]	valid_0's multi_logloss: 0.0459074
# [325]	valid_0's multi_logloss: 0.0457385
# [326]	valid_0's multi_logloss: 0.0456574
# [327]	valid_0's multi_logloss: 0.0454974
# [328]	valid_0's multi_logloss: 0.045366
# [329]	valid_0's multi_logloss: 0.0452198
# [330]	valid_0's multi_logloss: 0.045067
# [331]	valid_0's multi_logloss: 0.0449277
# [332]	valid_0's multi_logloss: 0.0448464
# [333]	valid_0's multi_logloss: 0.0447094
# [334]	valid_0's multi_logloss: 0.0445798
# [335]	valid_0's multi_logloss: 0.0444519
# [336]	valid_0's multi_logloss: 0.0443528
# [337]	valid_0's multi_logloss: 0.0442476
# [338]	valid_0's multi_logloss: 0.0440799
# [339]	valid_0's multi_logloss: 0.0439263
# [340]	valid_0's multi_logloss: 0.0438438
# [341]	valid_0's multi_logloss: 0.0437192
# [342]	valid_0's multi_logloss: 0.043612
# [343]	valid_0's multi_logloss: 0.0435662
# [344]	valid_0's multi_logloss: 0.043454
# [345]	valid_0's multi_logloss: 0.0433437
# [346]	valid_0's multi_logloss: 0.0432031
# [347]	valid_0's multi_logloss: 0.0430456
# [348]	valid_0's multi_logloss: 0.0429469
# [349]	valid_0's multi_logloss: 0.0428278
# [350]	valid_0's multi_logloss: 0.0426943
# [351]	valid_0's multi_logloss: 0.0425668
# [352]	valid_0's multi_logloss: 0.0425006
# [353]	valid_0's multi_logloss: 0.0424104
# [354]	valid_0's multi_logloss: 0.0422738
# [355]	valid_0's multi_logloss: 0.042149
# [356]	valid_0's multi_logloss: 0.0420132
# [357]	valid_0's multi_logloss: 0.0419324
# [358]	valid_0's multi_logloss: 0.0418347
# [359]	valid_0's multi_logloss: 0.0416935
# [360]	valid_0's multi_logloss: 0.0416275
# [361]	valid_0's multi_logloss: 0.041508
# [362]	valid_0's multi_logloss: 0.0414235
# [363]	valid_0's multi_logloss: 0.0413144
# [364]	valid_0's multi_logloss: 0.0412356
# [365]	valid_0's multi_logloss: 0.0411359
# [366]	valid_0's multi_logloss: 0.0410064
# [367]	valid_0's multi_logloss: 0.0409058
# [368]	valid_0's multi_logloss: 0.0407771
# [369]	valid_0's multi_logloss: 0.0407175
# [370]	valid_0's multi_logloss: 0.0406708
# [371]	valid_0's multi_logloss: 0.0405686
# [372]	valid_0's multi_logloss: 0.0404373
# [373]	valid_0's multi_logloss: 0.040365
# [374]	valid_0's multi_logloss: 0.0402412
# [375]	valid_0's multi_logloss: 0.0401077
# [376]	valid_0's multi_logloss: 0.0400525
# [377]	valid_0's multi_logloss: 0.0399382
# [378]	valid_0's multi_logloss: 0.0398098
# [379]	valid_0's multi_logloss: 0.0397212
# [380]	valid_0's multi_logloss: 0.0396054
# [381]	valid_0's multi_logloss: 0.0395331
# [382]	valid_0's multi_logloss: 0.0394219
# [383]	valid_0's multi_logloss: 0.0393265
# [384]	valid_0's multi_logloss: 0.0392556
# [385]	valid_0's multi_logloss: 0.0391702
# [386]	valid_0's multi_logloss: 0.0390803
# [387]	valid_0's multi_logloss: 0.0390233
# [388]	valid_0's multi_logloss: 0.0389807
# [389]	valid_0's multi_logloss: 0.0389164
# [390]	valid_0's multi_logloss: 0.0388463
# [391]	valid_0's multi_logloss: 0.0387463
# [392]	valid_0's multi_logloss: 0.0386661
# [393]	valid_0's multi_logloss: 0.0385763
# [394]	valid_0's multi_logloss: 0.0384322
# [395]	valid_0's multi_logloss: 0.0383673
# [396]	valid_0's multi_logloss: 0.038276
# [397]	valid_0's multi_logloss: 0.0381914
# [398]	valid_0's multi_logloss: 0.03812
# [399]	valid_0's multi_logloss: 0.0380043
# [400]	valid_0's multi_logloss: 0.0379207
# [401]	valid_0's multi_logloss: 0.0378652
# [402]	valid_0's multi_logloss: 0.0378174
# [403]	valid_0's multi_logloss: 0.0377377
# [404]	valid_0's multi_logloss: 0.0376214
# [405]	valid_0's multi_logloss: 0.0375357
# [406]	valid_0's multi_logloss: 0.0374572
# [407]	valid_0's multi_logloss: 0.0373911
# [408]	valid_0's multi_logloss: 0.0372709
# [409]	valid_0's multi_logloss: 0.0371682
# [410]	valid_0's multi_logloss: 0.0370936
# [411]	valid_0's multi_logloss: 0.0369796
# [412]	valid_0's multi_logloss: 0.0369236
# [413]	valid_0's multi_logloss: 0.0368374
# [414]	valid_0's multi_logloss: 0.0367449
# [415]	valid_0's multi_logloss: 0.0367103
# [416]	valid_0's multi_logloss: 0.0366469
# [417]	valid_0's multi_logloss: 0.0365786
# [418]	valid_0's multi_logloss: 0.0364883
# [419]	valid_0's multi_logloss: 0.036432
# [420]	valid_0's multi_logloss: 0.0363662
# [421]	valid_0's multi_logloss: 0.0363206
# [422]	valid_0's multi_logloss: 0.036248
# [423]	valid_0's multi_logloss: 0.036204
# [424]	valid_0's multi_logloss: 0.0361228
# [425]	valid_0's multi_logloss: 0.0360263
# [426]	valid_0's multi_logloss: 0.0359337
# [427]	valid_0's multi_logloss: 0.0358983
# [428]	valid_0's multi_logloss: 0.0358337
# [429]	valid_0's multi_logloss: 0.0357554
# [430]	valid_0's multi_logloss: 0.0356542
# [431]	valid_0's multi_logloss: 0.0355489
# [432]	valid_0's multi_logloss: 0.0354583
# [433]	valid_0's multi_logloss: 0.0354517
# [434]	valid_0's multi_logloss: 0.035393
# [435]	valid_0's multi_logloss: 0.0353063
# [436]	valid_0's multi_logloss: 0.0352141
# [437]	valid_0's multi_logloss: 0.0351635
# [438]	valid_0's multi_logloss: 0.0350823
# [439]	valid_0's multi_logloss: 0.0349996
# [440]	valid_0's multi_logloss: 0.0349374
# [441]	valid_0's multi_logloss: 0.0348293
# [442]	valid_0's multi_logloss: 0.0347795
# [443]	valid_0's multi_logloss: 0.0346822
# [444]	valid_0's multi_logloss: 0.034591
# [445]	valid_0's multi_logloss: 0.034555
# [446]	valid_0's multi_logloss: 0.0345228
# [447]	valid_0's multi_logloss: 0.0344588
# [448]	valid_0's multi_logloss: 0.0343679
# [449]	valid_0's multi_logloss: 0.0343179
# [450]	valid_0's multi_logloss: 0.0342368
# [451]	valid_0's multi_logloss: 0.034176
# [452]	valid_0's multi_logloss: 0.0340886
# [453]	valid_0's multi_logloss: 0.0340053
# [454]	valid_0's multi_logloss: 0.0339533
# [455]	valid_0's multi_logloss: 0.0338921
# [456]	valid_0's multi_logloss: 0.0338305
# [457]	valid_0's multi_logloss: 0.0337358
# [458]	valid_0's multi_logloss: 0.0336144
# [459]	valid_0's multi_logloss: 0.0335258
# [460]	valid_0's multi_logloss: 0.0334888
# [461]	valid_0's multi_logloss: 0.0334247
# [462]	valid_0's multi_logloss: 0.0333215
# [463]	valid_0's multi_logloss: 0.0332343
# [464]	valid_0's multi_logloss: 0.0331779
# [465]	valid_0's multi_logloss: 0.0331259
# [466]	valid_0's multi_logloss: 0.0331059
# [467]	valid_0's multi_logloss: 0.0330782
# [468]	valid_0's multi_logloss: 0.0330376
# [469]	valid_0's multi_logloss: 0.0329897
# [470]	valid_0's multi_logloss: 0.0329066
# [471]	valid_0's multi_logloss: 0.0328611
# [472]	valid_0's multi_logloss: 0.0327709
# [473]	valid_0's multi_logloss: 0.0327193
# ...
# [1055]	valid_0's multi_logloss: 0.0287866
# [1056]	valid_0's multi_logloss: 0.0287989
# [1057]	valid_0's multi_logloss: 0.0287697
# [1058]	valid_0's multi_logloss: 0.0287652
# [1059]	valid_0's multi_logloss: 0.0287401
# [1060]	valid_0's multi_logloss: 0.028722
# [1061]	valid_0's multi_logloss: 0.0287504
# [1062]	valid_0's multi_logloss: 0.0287562
# [1063]	valid_0's multi_logloss: 0.0287493
# [1064]	valid_0's multi_logloss: 0.028733
# [1065]	valid_0's multi_logloss: 0.0287134
# [1066]	valid_0's multi_logloss: 0.0287358
# [1067]	valid_0's multi_logloss: 0.0287397
# [1068]	valid_0's multi_logloss: 0.0287441
# [1069]	valid_0's multi_logloss: 0.0287575
# [1070]	valid_0's multi_logloss: 0.0287798
# [1071]	valid_0's multi_logloss: 0.0287399
# [1072]	valid_0's multi_logloss: 0.0287174
# [1073]	valid_0's multi_logloss: 0.0287374
# [1074]	valid_0's multi_logloss: 0.028751
# [1075]	valid_0's multi_logloss: 0.0287492
# [1076]	valid_0's multi_logloss: 0.0287254
# [1077]	valid_0's multi_logloss: 0.0287308
# [1078]	valid_0's multi_logloss: 0.028747
# [1079]	valid_0's multi_logloss: 0.0287524
# [1080]	valid_0's multi_logloss: 0.0287552
# [1081]	valid_0's multi_logloss: 0.0287559
# [1082]	valid_0's multi_logloss: 0.02878
# [1083]	valid_0's multi_logloss: 0.0287557
# [1084]	valid_0's multi_logloss: 0.0287473
# [1085]	valid_0's multi_logloss: 0.0287171
# [1086]	valid_0's multi_logloss: 0.0287161
# [1087]	valid_0's multi_logloss: 0.0287387
# [1088]	valid_0's multi_logloss: 0.028748
# [1089]	valid_0's multi_logloss: 0.0287647
# [1090]	valid_0's multi_logloss: 0.0287534
# [1091]	valid_0's multi_logloss: 0.0287547
# [1092]	valid_0's multi_logloss: 0.028754
# [1093]	valid_0's multi_logloss: 0.0287603
# [1094]	valid_0's multi_logloss: 0.0287606
# [1095]	valid_0's multi_logloss: 0.0287402
# [1096]	valid_0's multi_logloss: 0.0287302
# [1097]	valid_0's multi_logloss: 0.0287517
# [1098]	valid_0's multi_logloss: 0.0287771
# [1099]	valid_0's multi_logloss: 0.0287828
# [1100]	valid_0's multi_logloss: 0.028761
# [1101]	valid_0's multi_logloss: 0.0287421
# [1102]	valid_0's multi_logloss: 0.0287398
# [1103]	valid_0's multi_logloss: 0.0287368
# [1104]	valid_0's multi_logloss: 0.0287441
# [1105]	valid_0's multi_logloss: 0.0287312
# [1106]	valid_0's multi_logloss: 0.0287289
# [1107]	valid_0's multi_logloss: 0.0287465
# [1108]	valid_0's multi_logloss: 0.0287451
# [1109]	valid_0's multi_logloss: 0.0287759
# [1110]	valid_0's multi_logloss: 0.0287273
# [1111]	valid_0's multi_logloss: 0.0287354
# [1112]	valid_0's multi_logloss: 0.0287267
# [1113]	valid_0's multi_logloss: 0.0287221
# [1114]	valid_0's multi_logloss: 0.0287147
# [1115]	valid_0's multi_logloss: 0.0286983
# [1116]	valid_0's multi_logloss: 0.0287237
# [1117]	valid_0's multi_logloss: 0.0287176
# [1118]	valid_0's multi_logloss: 0.0287166
# [1119]	valid_0's multi_logloss: 0.0287058
# [1120]	valid_0's multi_logloss: 0.0286827
# [1121]	valid_0's multi_logloss: 0.0286584
# [1122]	valid_0's multi_logloss: 0.0286538
# [1123]	valid_0's multi_logloss: 0.0286197
# [1124]	valid_0's multi_logloss: 0.0286126
# [1125]	valid_0's multi_logloss: 0.0286478
# [1126]	valid_0's multi_logloss: 0.0286356
# [1127]	valid_0's multi_logloss: 0.0286041
# [1128]	valid_0's multi_logloss: 0.0286185
# [1129]	valid_0's multi_logloss: 0.0286158
# [1130]	valid_0's multi_logloss: 0.0286283
# [1131]	valid_0's multi_logloss: 0.0286369
# [1132]	valid_0's multi_logloss: 0.028605
# [1133]	valid_0's multi_logloss: 0.028624
# [1134]	valid_0's multi_logloss: 0.0286251
# [1135]	valid_0's multi_logloss: 0.0286239
# [1136]	valid_0's multi_logloss: 0.0286354
# [1137]	valid_0's multi_logloss: 0.0286587
# [1138]	valid_0's multi_logloss: 0.0286816
# [1139]	valid_0's multi_logloss: 0.0286879
# [1140]	valid_0's multi_logloss: 0.0287055
# [1141]	valid_0's multi_logloss: 0.0286778
# [1142]	valid_0's multi_logloss: 0.0286574
# [1143]	valid_0's multi_logloss: 0.0286562
# [1144]	valid_0's multi_logloss: 0.0286396
# [1145]	valid_0's multi_logloss: 0.0286536
# [1146]	valid_0's multi_logloss: 0.0286642
# [1147]	valid_0's multi_logloss: 0.0286774
# [1148]	valid_0's multi_logloss: 0.0286937
# [1149]	valid_0's multi_logloss: 0.0287153
# [1150]	valid_0's multi_logloss: 0.0287062
# [1151]	valid_0's multi_logloss: 0.02867
# [1152]	valid_0's multi_logloss: 0.0286865
# [1153]	valid_0's multi_logloss: 0.0287129
# [1154]	valid_0's multi_logloss: 0.0287367
# [1155]	valid_0's multi_logloss: 0.0287438
# [1156]	valid_0's multi_logloss: 0.0287222
# [1157]	valid_0's multi_logloss: 0.0287286
# [1158]	valid_0's multi_logloss: 0.0287147
# [1159]	valid_0's multi_logloss: 0.0286857
# [1160]	valid_0's multi_logloss: 0.0286899
# [1161]	valid_0's multi_logloss: 0.0286597
# [1162]	valid_0's multi_logloss: 0.0286715
# [1163]	valid_0's multi_logloss: 0.0286632
# [1164]	valid_0's multi_logloss: 0.0286569
# [1165]	valid_0's multi_logloss: 0.0286952
# [1166]	valid_0's multi_logloss: 0.0287051
# [1167]	valid_0's multi_logloss: 0.0286911
# [1168]	valid_0's multi_logloss: 0.028687
# [1169]	valid_0's multi_logloss: 0.028698
# [1170]	valid_0's multi_logloss: 0.0287087
# [1171]	valid_0's multi_logloss: 0.0287008
# [1172]	valid_0's multi_logloss: 0.0287071
# [1173]	valid_0's multi_logloss: 0.0286842
# [1174]	valid_0's multi_logloss: 0.0287059
# [1175]	valid_0's multi_logloss: 0.0286972
# [1176]	valid_0's multi_logloss: 0.0286932
# [1177]	valid_0's multi_logloss: 0.0287027
# [1178]	valid_0's multi_logloss: 0.028692
# [1179]	valid_0's multi_logloss: 0.0286952
# [1180]	valid_0's multi_logloss: 0.0286745
# [1181]	valid_0's multi_logloss: 0.0287031
# [1182]	valid_0's multi_logloss: 0.0286986
# [1183]	valid_0's multi_logloss: 0.0287183
# [1184]	valid_0's multi_logloss: 0.0287273
# [1185]	valid_0's multi_logloss: 0.0287397
# [1186]	valid_0's multi_logloss: 0.0287698
# [1187]	valid_0's multi_logloss: 0.0287814
# [1188]	valid_0's multi_logloss: 0.0287982
# [1189]	valid_0's multi_logloss: 0.02876
# [1190]	valid_0's multi_logloss: 0.0287993
# [1191]	valid_0's multi_logloss: 0.0288108
# [1192]	valid_0's multi_logloss: 0.028822
# [1193]	valid_0's multi_logloss: 0.0288276
# [1194]	valid_0's multi_logloss: 0.0288352
# [1195]	valid_0's multi_logloss: 0.0288354
# [1196]	valid_0's multi_logloss: 0.0288099
# [1197]	valid_0's multi_logloss: 0.0288071
# [1198]	valid_0's multi_logloss: 0.0288021
# [1199]	valid_0's multi_logloss: 0.0288172
# [1200]	valid_0's multi_logloss: 0.0288237
# [1201]	valid_0's multi_logloss: 0.0288099
# [1202]	valid_0's multi_logloss: 0.0287725
# [1203]	valid_0's multi_logloss: 0.0287842
# [1204]	valid_0's multi_logloss: 0.028813
# [1205]	valid_0's multi_logloss: 0.0288091
# [1206]	valid_0's multi_logloss: 0.0287779
# [1207]	valid_0's multi_logloss: 0.028772
# [1208]	valid_0's multi_logloss: 0.0287652
# [1209]	valid_0's multi_logloss: 0.0287667
# [1210]	valid_0's multi_logloss: 0.0287743
# [1211]	valid_0's multi_logloss: 0.0287948
# [1212]	valid_0's multi_logloss: 0.0287901
# [1213]	valid_0's multi_logloss: 0.0287808
# [1214]	valid_0's multi_logloss: 0.0287554
# [1215]	valid_0's multi_logloss: 0.0287475
# [1216]	valid_0's multi_logloss: 0.0287718
# [1217]	valid_0's multi_logloss: 0.0287777
# [1218]	valid_0's multi_logloss: 0.0287473
# [1219]	valid_0's multi_logloss: 0.0287352
# [1220]	valid_0's multi_logloss: 0.0287621
# [1221]	valid_0's multi_logloss: 0.0287562
# [1222]	valid_0's multi_logloss: 0.0287293
# [1223]	valid_0's multi_logloss: 0.0287236
# [1224]	valid_0's multi_logloss: 0.028749
# [1225]	valid_0's multi_logloss: 0.0287464
# [1226]	valid_0's multi_logloss: 0.0287437
# [1227]	valid_0's multi_logloss: 0.0287571
# [1228]	valid_0's multi_logloss: 0.0287462
# [1229]	valid_0's multi_logloss: 0.0287503
# [1230]	valid_0's multi_logloss: 0.0287325
# [1231]	valid_0's multi_logloss: 0.0287362
# [1232]	valid_0's multi_logloss: 0.0287444
# [1233]	valid_0's multi_logloss: 0.0287535
# [1234]	valid_0's multi_logloss: 0.0287419
# [1235]	valid_0's multi_logloss: 0.0287418
# [1236]	valid_0's multi_logloss: 0.0287484
# [1237]	valid_0's multi_logloss: 0.0287309
# [1238]	valid_0's multi_logloss: 0.0287059
# [1239]	valid_0's multi_logloss: 0.0287345
# [1240]	valid_0's multi_logloss: 0.0287392
# [1241]	valid_0's multi_logloss: 0.0287135
# [1242]	valid_0's multi_logloss: 0.0287163
# [1243]	valid_0's multi_logloss: 0.0286912
# [1244]	valid_0's multi_logloss: 0.0286937
# [1245]	valid_0's multi_logloss: 0.0287015
# [1246]	valid_0's multi_logloss: 0.0286835
# [1247]	valid_0's multi_logloss: 0.0287006
# [1248]	valid_0's multi_logloss: 0.0287216
# [1249]	valid_0's multi_logloss: 0.0287081
# [1250]	valid_0's multi_logloss: 0.0287097
# [1251]	valid_0's multi_logloss: 0.0287411
# [1252]	valid_0's multi_logloss: 0.028744
# [1253]	valid_0's multi_logloss: 0.0287461
# [1254]	valid_0's multi_logloss: 0.0287601
# [1255]	valid_0's multi_logloss: 0.0287536
# [1256]	valid_0's multi_logloss: 0.0287613
# [1257]	valid_0's multi_logloss: 0.0287799
# [1258]	valid_0's multi_logloss: 0.0287863
# [1259]	valid_0's multi_logloss: 0.0287807
# [1260]	valid_0's multi_logloss: 0.0288014
# [1261]	valid_0's multi_logloss: 0.0288173
# [1262]	valid_0's multi_logloss: 0.028814
# [1263]	valid_0's multi_logloss: 0.0288241
# [1264]	valid_0's multi_logloss: 0.0288501
# [1265]	valid_0's multi_logloss: 0.0288709
# [1266]	valid_0's multi_logloss: 0.0288912
# [1267]	valid_0's multi_logloss: 0.0288538
# [1268]	valid_0's multi_logloss: 0.0288299
# [1269]	valid_0's multi_logloss: 0.0288225
# [1270]	valid_0's multi_logloss: 0.0288431
# [1271]	valid_0's multi_logloss: 0.0288717
# [1272]	valid_0's multi_logloss: 0.028884
# [1273]	valid_0's multi_logloss: 0.0289014
# [1274]	valid_0's multi_logloss: 0.0289001
# [1275]	valid_0's multi_logloss: 0.0289191
# [1276]	valid_0's multi_logloss: 0.0289361
# [1277]	valid_0's multi_logloss: 0.028937
# [1278]	valid_0's multi_logloss: 0.028939
# [1279]	valid_0's multi_logloss: 0.0289215
# [1280]	valid_0's multi_logloss: 0.0288973
# [1281]	valid_0's multi_logloss: 0.0288715
# [1282]	valid_0's multi_logloss: 0.0288728
# [1283]	valid_0's multi_logloss: 0.0288556
# [1284]	valid_0's multi_logloss: 0.0288694
# [1285]	valid_0's multi_logloss: 0.0289288
# [1286]	valid_0's multi_logloss: 0.0289476
# [1287]	valid_0's multi_logloss: 0.028966
# [1288]	valid_0's multi_logloss: 0.0289801
# [1289]	valid_0's multi_logloss: 0.0289935
# [1290]	valid_0's multi_logloss: 0.0289921
# [1291]	valid_0's multi_logloss: 0.028984
# [1292]	valid_0's multi_logloss: 0.0290149
# [1293]	valid_0's multi_logloss: 0.0290258
# [1294]	valid_0's multi_logloss: 0.0290304
# [1295]	valid_0's multi_logloss: 0.0290396
# [1296]	valid_0's multi_logloss: 0.0290536
# [1297]	valid_0's multi_logloss: 0.0290481
# [1298]	valid_0's multi_logloss: 0.0290577
# [1299]	valid_0's multi_logloss: 0.0290405
# [1300]	valid_0's multi_logloss: 0.0290555
# [1301]	valid_0's multi_logloss: 0.029051
# [1302]	valid_0's multi_logloss: 0.0290634
# [1303]	valid_0's multi_logloss: 0.02906
# [1304]	valid_0's multi_logloss: 0.0290728
# [1305]	valid_0's multi_logloss: 0.0290834
# [1306]	valid_0's multi_logloss: 0.0290964
# [1307]	valid_0's multi_logloss: 0.0290929
# [1308]	valid_0's multi_logloss: 0.0290865
# [1309]	valid_0's multi_logloss: 0.0290843
# [1310]	valid_0's multi_logloss: 0.0290997
# [1311]	valid_0's multi_logloss: 0.0290901
# [1312]	valid_0's multi_logloss: 0.0290813
# [1313]	valid_0's multi_logloss: 0.0290841
# [1314]	valid_0's multi_logloss: 0.0290851
# [1315]	valid_0's multi_logloss: 0.029072
# [1316]	valid_0's multi_logloss: 0.0290714
# [1317]	valid_0's multi_logloss: 0.0290873
# [1318]	valid_0's multi_logloss: 0.0291274
# [1319]	valid_0's multi_logloss: 0.0291472
# [1320]	valid_0's multi_logloss: 0.0291642
# [1321]	valid_0's multi_logloss: 0.0291727
# [1322]	valid_0's multi_logloss: 0.0291756
# [1323]	valid_0's multi_logloss: 0.0291667
# [1324]	valid_0's multi_logloss: 0.0291737
# [1325]	valid_0's multi_logloss: 0.0291902
# [1326]	valid_0's multi_logloss: 0.0291907
# [1327]	valid_0's multi_logloss: 0.0291888
# [1328]	valid_0's multi_logloss: 0.029208
# [1329]	valid_0's multi_logloss: 0.0291864
# [1330]	valid_0's multi_logloss: 0.029217
# [1331]	valid_0's multi_logloss: 0.0292267
# [1332]	valid_0's multi_logloss: 0.0292405
# [1333]	valid_0's multi_logloss: 0.0292528
# [1334]	valid_0's multi_logloss: 0.0292577
# [1335]	valid_0's multi_logloss: 0.0292767
# [1336]	valid_0's multi_logloss: 0.0292985
# [1337]	valid_0's multi_logloss: 0.0292737
# [1338]	valid_0's multi_logloss: 0.0292893
# [1339]	valid_0's multi_logloss: 0.0292783
# [1340]	valid_0's multi_logloss: 0.0292519
# [1341]	valid_0's multi_logloss: 0.029273
# [1342]	valid_0's multi_logloss: 0.0292835
# [1343]	valid_0's multi_logloss: 0.0292783
# [1344]	valid_0's multi_logloss: 0.0292989
# [1345]	valid_0's multi_logloss: 0.0293024
# [1346]	valid_0's multi_logloss: 0.0292743
# [1347]	valid_0's multi_logloss: 0.0292923
# [1348]	valid_0's multi_logloss: 0.0293097
# [1349]	valid_0's multi_logloss: 0.0292976
# [1350]	valid_0's multi_logloss: 0.0293303
# [1351]	valid_0's multi_logloss: 0.0293263
# [1352]	valid_0's multi_logloss: 0.0293123
# [1353]	valid_0's multi_logloss: 0.0292961
# [1354]	valid_0's multi_logloss: 0.0292875
# [1355]	valid_0's multi_logloss: 0.0292866
# [1356]	valid_0's multi_logloss: 0.0292922
# [1357]	valid_0's multi_logloss: 0.029289
# [1358]	valid_0's multi_logloss: 0.0292907
# [1359]	valid_0's multi_logloss: 0.0292851
# [1360]	valid_0's multi_logloss: 0.0292921
# [1361]	valid_0's multi_logloss: 0.0292942
# [1362]	valid_0's multi_logloss: 0.0293067
# [1363]	valid_0's multi_logloss: 0.0292884
# [1364]	valid_0's multi_logloss: 0.0292804
# [1365]	valid_0's multi_logloss: 0.0293057
# [1366]	valid_0's multi_logloss: 0.0293243
# [1367]	valid_0's multi_logloss: 0.0293334
# [1368]	valid_0's multi_logloss: 0.0293409
# [1369]	valid_0's multi_logloss: 0.029326
# [1370]	valid_0's multi_logloss: 0.0293472
# [1371]	valid_0's multi_logloss: 0.0293627
# [1372]	valid_0's multi_logloss: 0.0293527
# [1373]	valid_0's multi_logloss: 0.0293566
# [1374]	valid_0's multi_logloss: 0.0293497
# [1375]	valid_0's multi_logloss: 0.0293681
# [1376]	valid_0's multi_logloss: 0.0293403
# [1377]	valid_0's multi_logloss: 0.0293306
# [1378]	valid_0's multi_logloss: 0.029341
# [1379]	valid_0's multi_logloss: 0.0293668
# [1380]	valid_0's multi_logloss: 0.0293679
# [1381]	valid_0's multi_logloss: 0.0293506
# [1382]	valid_0's multi_logloss: 0.0293333
# [1383]	valid_0's multi_logloss: 0.02932
# [1384]	valid_0's multi_logloss: 0.0293045
# [1385]	valid_0's multi_logloss: 0.0293058
# [1386]	valid_0's multi_logloss: 0.0293123
# [1387]	valid_0's multi_logloss: 0.0293064
# [1388]	valid_0's multi_logloss: 0.02932
# [1389]	valid_0's multi_logloss: 0.0293199
# [1390]	valid_0's multi_logloss: 0.0293332
# [1391]	valid_0's multi_logloss: 0.0293117
# [1392]	valid_0's multi_logloss: 0.0293169
# [1393]	valid_0's multi_logloss: 0.0293268
# [1394]	valid_0's multi_logloss: 0.0293255
# [1395]	valid_0's multi_logloss: 0.0293293
# [1396]	valid_0's multi_logloss: 0.0293062
# [1397]	valid_0's multi_logloss: 0.0293502
# [1398]	valid_0's multi_logloss: 0.0293614
# [1399]	valid_0's multi_logloss: 0.0293607
# [1400]	valid_0's multi_logloss: 0.0293578
# [1401]	valid_0's multi_logloss: 0.0293735
# [1402]	valid_0's multi_logloss: 0.0293566
# [1403]	valid_0's multi_logloss: 0.0293568
# [1404]	valid_0's multi_logloss: 0.0293673
# [1405]	valid_0's multi_logloss: 0.0293818
# [1406]	valid_0's multi_logloss: 0.0294097
# [1407]	valid_0's multi_logloss: 0.0293986
# [1408]	valid_0's multi_logloss: 0.0294063
# [1409]	valid_0's multi_logloss: 0.0294377
# [1410]	valid_0's multi_logloss: 0.0294436
# [1411]	valid_0's multi_logloss: 0.0294463
# [1412]	valid_0's multi_logloss: 0.029465
# [1413]	valid_0's multi_logloss: 0.0294565
# [1414]	valid_0's multi_logloss: 0.0294876
# [1415]	valid_0's multi_logloss: 0.0294929
# [1416]	valid_0's multi_logloss: 0.0294571
# [1417]	valid_0's multi_logloss: 0.0294671
# [1418]	valid_0's multi_logloss: 0.0294653
# [1419]	valid_0's multi_logloss: 0.0294703
# [1420]	valid_0's multi_logloss: 0.029483
# [1421]	valid_0's multi_logloss: 0.0294715
# [1422]	valid_0's multi_logloss: 0.0294689
# [1423]	valid_0's multi_logloss: 0.0294404
# [1424]	valid_0's multi_logloss: 0.0294358
# [1425]	valid_0's multi_logloss: 0.0294232
# [1426]	valid_0's multi_logloss: 0.0294152
# [1427]	valid_0's multi_logloss: 0.029442
# Early stopping, best iteration is:
# [1127]	valid_0's multi_logloss: 0.0286041
# Fold n°10 on LGBM. AUC : 1.000 | Accuracy : 98.9%
#
# LGBM after BayesianGaussianMixture - threshold 0.69 : Silhouette : 2.8% | Calinski Harabasz : 3276.6 | Davis Bouldin : 4.312
# balanced_accuracy_score    0.991155
# roc_auc_score              0.999926
# dtype: float64

# %%
et_predict_proba = 0 ; classif_scores = []

gkf = StratifiedKFold(N_FOLDS, shuffle=True, random_state = SEED + 1)

for fold, (trn_idx, val_idx) in enumerate(gkf.split(X, y)):   

    X_trn, y_trn = X.iloc[trn_idx], y.iloc[trn_idx]
    X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]
    
    model = ExtraTreesClassifier(n_estimators=100, random_state=SEED)
    model.fit(X_trn, y_trn)
    
    y_pred = model.predict(X_val)
    y_pred_proba = model.predict_proba(X_val)
    
    s = (balanced_accuracy_score(y_val, y_pred),
        roc_auc_score(y_val, y_pred_proba, average="weighted", multi_class="ovo"))
    print(f"Fold n°{fold+1} on Extratree. AUC : {s[1]:.3f} | Accuracy : {s[0]:.1%}")
    classif_scores.append(s)

    et_predict_proba += model.predict_proba(data[best_feats]) / N_FOLDS

all_scores.append(scores(np.argmax(et_predict_proba, axis=1), lib="Extratree after BayesianGaussianMixture"))

pd.DataFrame(classif_scores, columns = ["balanced_accuracy_score", "roc_auc_score"]).mean(0)

# %%
qda_predict_proba = 0 ; classif_scores = []

gkf = StratifiedKFold(N_FOLDS, shuffle=True, random_state = SEED + 2)

for fold, (trn_idx, val_idx) in enumerate(gkf.split(X, y)):   

    X_trn, y_trn = X.iloc[trn_idx], y.iloc[trn_idx]
    X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]

    model = QuadraticDiscriminantAnalysis(reg_param=1)
    model.fit(X_trn, y_trn) # on trusted data only
    
    y_pred = model.predict(X_val)
    y_pred_proba = model.predict_proba(X_val)
    
    s = (balanced_accuracy_score(y_val, y_pred),
        roc_auc_score(y_val, y_pred_proba, average="weighted", multi_class="ovo"))
    print(f"Fold n°{fold+1} on QDA. AUC : {s[1]:.3f} | Accuracy : {s[0]:.1%}")
    classif_scores.append(s)

    qda_predict_proba += model.predict_proba(data[best_feats]) / N_FOLDS

all_scores.append(scores(np.argmax(qda_predict_proba, axis=1), lib="QuadraticDiscriminantAnalysis n°1 after BayesianGaussianMixture"))
pd.DataFrame(classif_scores, columns = ["balanced_accuracy_score", "roc_auc_score"]).mean(0)

# %%
qda_predict_proba = 0 ; classif_scores = []

gkf = StratifiedKFold(N_FOLDS, shuffle=True, random_state = SEED + 2)

for fold, (trn_idx, val_idx) in enumerate(gkf.split(X, y)):   

    X_trn, y_trn = X.iloc[trn_idx], y.iloc[trn_idx]
    X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]

    model = QuadraticDiscriminantAnalysis(reg_param=0)
    model.fit(X_trn, y_trn) # on trusted data only
    
    y_pred = model.predict(X_val)
    y_pred_proba = model.predict_proba(X_val)
    
    s = (balanced_accuracy_score(y_val, y_pred),
        roc_auc_score(y_val, y_pred_proba, average="weighted", multi_class="ovo"))
    print(f"Fold n°{fold+1} on QDA. AUC : {s[1]:.3f} | Accuracy : {s[0]:.1%}")
    classif_scores.append(s)

    qda_predict_proba += model.predict_proba(data[best_feats]) / N_FOLDS

all_scores.append(scores(np.argmax(qda_predict_proba, axis=1), lib="QuadraticDiscriminantAnalysis n°2 after BayesianGaussianMixture"))
pd.DataFrame(classif_scores, columns = ["balanced_accuracy_score", "roc_auc_score"]).mean(0)

# %%
GNB_predict_proba = 0 ; classif_scores = []

gkf = StratifiedKFold(N_FOLDS, shuffle=True, random_state = SEED + 2)

for fold, (trn_idx, val_idx) in enumerate(gkf.split(X, y)):   

    X_trn, y_trn = X.iloc[trn_idx], y.iloc[trn_idx]
    X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]

    model = GaussianNB(var_smoothing=.1)
    model.fit(X_trn, y_trn) # on trusted data only
    
    y_pred = model.predict(X_val)
    y_pred_proba = model.predict_proba(X_val)
    
    s = (balanced_accuracy_score(y_val, y_pred),
        roc_auc_score(y_val, y_pred_proba, average="weighted", multi_class="ovo"))
    print(f"Fold n°{fold+1} on GaussianNB. AUC : {s[1]:.3f} | Accuracy : {s[0]:.1%}")
    classif_scores.append(s)

    GNB_predict_proba += model.predict_proba(data[best_feats]) / N_FOLDS

all_scores.append(scores(np.argmax(GNB_predict_proba, axis=1), lib="GaussianNaïveBayes after BayesianGaussianMixture"))
pd.DataFrame(classif_scores, columns = ["balanced_accuracy_score", "roc_auc_score"]).mean(0)

# %%
lda_predict_proba = 0 ; classif_scores = []

gkf = StratifiedKFold(N_FOLDS, shuffle=True, random_state = SEED + 2)

for fold, (trn_idx, val_idx) in enumerate(gkf.split(X, y)):   

    X_trn, y_trn = X.iloc[trn_idx], y.iloc[trn_idx]
    X_val, y_val = X.iloc[val_idx], y.iloc[val_idx]

    model = LinearDiscriminantAnalysis()
    model.fit(X_trn, y_trn) # on trusted data only
    
    y_pred = model.predict(X_val)
    y_pred_proba = model.predict_proba(X_val)
    
    s = (balanced_accuracy_score(y_val, y_pred),
        roc_auc_score(y_val, y_pred_proba, average="weighted", multi_class="ovo"))
    print(f"Fold n°{fold+1} on LDA. AUC : {s[1]:.3f} | Accuracy : {s[0]:.1%}")
    classif_scores.append(s)

    lda_predict_proba += model.predict_proba(data[best_feats]) / N_FOLDS

all_scores.append(scores(np.argmax(lda_predict_proba, axis=1), lib="LinearDiscriminantAnalysis after BayesianGaussianMixture"))
pd.DataFrame(classif_scores, columns = ["balanced_accuracy_score", "roc_auc_score"]).mean(0)

# %%
def soft_voting(preds_probs):

    values = list(range(N_CLUSTERS))
    pred_test = pd.DataFrame(np.zeros((data.shape[0], 7)), columns = values)

    for i, p in enumerate(preds_probs):
    
        MAX = np.argmax(p, axis=1)
        data[f'pred_{i}'] = MAX
    
        # Sort of the prediction by same value of cluster
        pred_keys = data[f'pred_{i}'].value_counts().index.tolist()
        pred_dict = dict(zip(pred_keys, values))
        data[f'pred_{i}'] = data[f'pred_{i}'].map(pred_dict)

        pred_new = pd.DataFrame(p).rename(columns = pred_dict)
        pred_new = pred_new.reindex(sorted(pred_new.columns), axis=1)
        pred_test += pred_new # Soft voting by probabiliy addition

    return np.argmax(np.array(pred_test), axis=1)

# %%
sv1_predict = soft_voting([et_predict_proba, lgbm_predict_proba, qda_predict_proba, lda_predict_proba, GNB_predict_proba])
all_scores.append(scores(sv1_predict, lib="Soft voting n°1 : all"))

sv2_predict = soft_voting([et_predict_proba, lgbm_predict_proba, qda_predict_proba])
all_scores.append(scores(sv2_predict, lib="Soft voting n°2 : LGBM, extratree and QDA"))

sv3_predict = soft_voting([lgbm_predict_proba, qda_predict_proba])
all_scores.append(scores(sv3_predict, lib="Soft voting n°3 : LGBM and QDA"))

# %%
pd.DataFrame(all_scores, columns=["Model", "silhouette", "Calinski_Harabasz", "Davis_Bouldin"])

# %%
sub['Predicted'] = np.argmax(lgbm_predict_proba, axis = 1)
sub.to_csv(PATH+"submissions/submission_lgbm_all_feats.csv",index = "Id")

sub['Predicted'] = np.argmax(et_predict_proba, axis = 1)
sub.to_csv(PATH+"submissions/submission_extratree_all_feats.csv", index = "Id")
 
sub['Predicted'] = np.argmax(qda_predict_proba, axis = 1)
sub.to_csv(PATH+"submissions/submission_qda_all_feats.csv", index = "Id")
 
sub['Predicted'] = np.argmax(lda_predict_proba, axis = 1)
sub.to_csv(PATH+"submissions/submission_lda_all_feats.csv", index = "Id")
 
sub['Predicted'] = np.argmax(GNB_predict_proba, axis = 1)
sub.to_csv(PATH+"submissions/submission_GNB_all_feats.csv", index = "Id")
 
sub['Predicted'] = sv1_predict
sub.to_csv(PATH+"submissions/submission_softvote1_all_feats.csv", index = "Id")

sub['Predicted'] = sv2_predict
sub.to_csv(PATH+"submissions/submission_softvote2_all_feats.csv", index = "Id")

sub['Predicted'] = sv3_predict
sub.to_csv(PATH+"submissions/submission_softvote3_all_feats.csv", index = "Id")

# %%
sub
# Out:
#        Predicted
# Id
# 0              4
# 1              1
# 2              0
# 3              0
# 4              2
# ...          ...
# 97995          0
# 97996          3
# 97997          2
# 97998          2
# 97999          1
#
# [98000 rows x 1 columns]
